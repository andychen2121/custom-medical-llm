# %% [markdown]
# ## setup

# %%
# !pip install ipyfilechooser
# !pip install layoutparser
# Out:
# Requirement already satisfied: ipyfilechooser in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: ipywidgets in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipyfilechooser) (8.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser) (3.0.8)
# Requirement already satisfied: appnope in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (1.5.6)
# Requirement already satisfied: packaging in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (23.0)
# Requirement already satisfied: psutil in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (6.2)
# Requirement already satisfied: backcall in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.2.0)
# Requirement already satisfied: decorator in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (2.15.1)
# Requirement already satisfied: stack-data in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.2.5)
# Requirement already satisfied: executing in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.8.3)
# Requirement already satisfied: asttokens in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (2.5.2)
# Requirement already satisfied: six>=1.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (1.16.0)
# Requirement already satisfied: layoutparser in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (0.3.4)
# Requirement already satisfied: numpy in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (1.25.0)
# Requirement already satisfied: opencv-python in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (4.8.0.76)
# Requirement already satisfied: scipy in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (1.10.1)
# Requirement already satisfied: pandas in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (1.5.3)
# Requirement already satisfied: pillow in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (9.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (6.0)
# Requirement already satisfied: iopath in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (0.1.10)
# Requirement already satisfied: pdfplumber in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (0.10.2)
# Requirement already satisfied: pdf2image in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from layoutparser) (1.16.3)
# Requirement already satisfied: tqdm in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from iopath->layoutparser) (4.65.0)
# Requirement already satisfied: typing-extensions in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from iopath->layoutparser) (4.7.1)
# Requirement already satisfied: portalocker in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from iopath->layoutparser) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pandas->layoutparser) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pandas->layoutparser) (2022.7)
# Requirement already satisfied: pdfminer.six==20221105 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pdfplumber->layoutparser) (20221105)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pdfplumber->layoutparser) (4.21.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (39.0.1)
# Requirement already satisfied: six>=1.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->layoutparser) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (1.15.1)
# Requirement already satisfied: pycparser in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (2.21)

# %%
from typing import List, Dict, Tuple, Set

from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from pathlib import Path
import nltk
from ipyfilechooser import FileChooser
import ipywidgets
import layoutparser as lp
import re

import pdfplumber

# %%
import os
DATA = Path("scrape_out")
assert DATA.is_dir()

# %% [markdown]
# # processing text

# %%
TOK_SENTENCE_TERMS = ('.','!','?')
TOK_SENTENCE_CONTS = (',',':',';')
TERM_PUNC_STR = "".join(TOK_SENTENCE_TERMS)

def ends_with(txt, terms=('.','!','?', ':')) -> bool:
    return txt and txt.rstrip().endswith(terms)

# %% [markdown]
# ## hyphen
#
# - __TODO__ implement trie datastructure for more efficient searching of words; have hyphen be root node?

# %%
# nltk.download('wordnet')
# nltk.download('wordnet31')
from nltk.corpus import wordnet31 as wordnet

hyphen_corpus = set(filter(lambda w: "-" in w, wordnet.words()))    # select just words with hyphen
hyphen_corpus = hyphen_corpus.union({'Three-dimensional', 'Multiple-detector', 'Two-and', 'Multiple-detector', 'four-detector-row','Post-expiratory','soft-tissue','two-or','arrowhead-shaped','fat-filled','short-axis','out-flow','mirror-image','left-sided','Contrast-enhanced','post-traumatic','x-rays','medullary-based','MDCT-guided','volume-rendered','volume-rendering','contrast-opacified','thick-walled','thin-walled','bolus-contrast-enhanced','Contrast-filled','smooth-outlined','sheet-like','small-bowel','Colon-wall','tumor-involved','Early-stage','Closed-loop','B-cell','Mucosa-associated','three-layer','region-of-interest','lipid-rich','Lipid-poor', 'non-Hodgkin’s','fat-containing','bone-marrow','Thin-section','Axial-plane','sagittal-plane','well-hydrated','end-stage','image-guided','fluid-filled','non-neoplastic','hairline-thin','well-marginated','Lymphad-enectomy','Nephron-sparing','mid-T-12','CT-KUB','CT-IVP','water-density','bunch-of-grapes','main-duct','branch-duct','duct-obstructing','AIDS-related','Hormone-producing','ultrasound-guided','Long-segment','upper-quadrant','IV-A','IV-B','tech-netium-99m-labeled','technetium-99m','delayed-phase','Well-differentiated','venous-phase','arterial-phase','arterial-phase','nodule-in-nodule','False-positive','comma-shaped',})
hyphen_corpus = set(map(lambda w: w.lower(), hyphen_corpus))    # lower case

len(hyphen_corpus)
# Out:
# 7124

# %%
hyphen_prefixs = {'high', 'higher', 'highest',
                  'low', 'lower', 'lowest',
                  'max', 'maximum',
                  'min', 'minimum',
                  }

hyphen_sufffixs = {'mm', 'cm', 'm'}

# %%
def dehyphenate_string(input_string, pg_num=None):
    out = ""
    dehyphens = []

    # remove surronding space from either left or right -- but don't conjoin
    if re.search(r"\w\s+-\s+\w", input_string):
        return input_string, dehyphens
    input_string = re.sub(r"\s*-\s*", r"-", input_string)   

    re_number       = r'^\d+(\.\d+)?-(.+)$'      # e.x. 15.25-mm
    re_word_extract = r'^(\W*)([\w’-]*)(\W*)$'
    re_hyph_split   = r'^([^-]*)-(.*)$'

    words = re.split(r'(?<=[\s+])', input_string)    # this will split, but preserve the whitespace
    for full_word in words:
        if not full_word: continue
        if "-" not in full_word or re.search(re_number, full_word):
            out += full_word
            continue
        
        try:
            match = re.search(re_word_extract, full_word)
            pre, word, post = match.groups()
            
            # assert '-' in word
            if '-' not in word:
                print(f"{word} has an assertion error!")
                continue

            match = re.search(re_hyph_split, word)
            word_pre, word_post = match.groups()
        except AttributeError:
            print(f"###{f' PG {pg_num} ::' if pg_num else ''} Failed to dehyphenate word: {full_word}")
            out += full_word
            continue
        
        if word_pre.lower() not in hyphen_prefixs and word_post.lower() not in hyphen_sufffixs:
            if word.lower() not in hyphen_corpus:
                # print('Dehyphenating word: ', word)
                dehyphens.append(word)
                word = word_pre + word_post
        out += pre + word + post
    return out, dehyphens


assert (res:=dehyphenate_string((txt:="Non-Hodgkin’s"))) == (txt,[]), res
assert (res:=dehyphenate_string((txt:="max-something"))) == (txt,[]), res
assert (res:=dehyphenate_string((txt:="max -something"))) == ("max-something",[]), res  # remove inner spaces
assert (res:=dehyphenate_string((txt:="max- something"))) == ("max-something",[]), res  # remove inner spaces
assert (res:=dehyphenate_string((txt:="max - something"))) == (txt,[]), res  # don't conjoin
assert (res:=dehyphenate_string((txt:="minimum-otherthing"))) == (txt,[]), res
assert (res:=dehyphenate_string((txt:="highest-otherthing"))) == (txt,[]), res
assert (res:=dehyphenate_string((txt:="False Positives: x-ray is a hyphenated word. 15.25-mm is a hyphenated number."))) == (txt,[]), res
assert (res:=dehyphenate_string( \
    (txt:="True Positive: This is an ex-ample of a de-hyphenated string"))) == \
    ("True Positive: This is an example of a dehyphenated string",['ex-ample', 'de-hyphenated']), res
assert (res:=dehyphenate_string((txt:=" Floats + keeps outer whitespace: Gantry rotation time is usually about 0.5 seconds. "))) == (txt,[]), res

# %% [markdown]
# ## figures, tables, misc.

# %%
def process_text(text: str, log=False, pg_num=None, placeholder=None) -> str:
    placeholder = placeholder or "" 
    
    text = re.sub(r"(["+TERM_PUNC_STR+','+r"])([a-z][^\.] ?)", r"\1 \2", text, flags=re.IGNORECASE)    # e.x. abc.def -> abc. def; but not e.g. -> e. g.
    text = re.sub(r"figs?\.", "figure", text, flags=re.IGNORECASE)    # because we are splitting on '.', we need to replace 'Fig.' with 'figure'
    text = re.sub(r"(figure|table|image)s?\s+\d+\.", r"\1 ", text, flags=re.IGNORECASE)    # because we are splitting on '.', we need to replace 'figure 9.' with 'figure'
    text = re.sub(r"([\)\]\}])(\w)", r"\1 \2", text)    # e.x. (lorem)ipsum -> (lorem) ipsum
    text = re.sub(r"(\w)([\(\[\{])", r"\1 \2", text)    # e.x. lorem(ipsum) -> lorem (ipsum)
    text = re.sub(r"([a-z])([\d])", r"\1 \2", text, flags=re.IGNORECASE)    # e.x. abc1 -> abc 1
    text = re.sub(r"([a-ln-z])([A-Z])", r"\1 \2", text)    # e.x. abcDef -> abc Def; but not m* e.x. mA, mSv
    text = re.sub(r"([’']s)(\w)", r"\1 \2", text)    # e.x. 'sA -> 's A
    
    out = ""
    sentences = re.split(r'(?<=['+TERM_PUNC_STR+r'] )', text)    # this will split, but preserve the delimiter
    # print(sentences)
    for sent in sentences:
        if not sent: continue
        
        # TODO implement placeholder; give more context to downstream processing         
        ref_whole = r"([fF](igure|IGURE)|[tT](able|ABLE)|[iI](mage|MAGE))\s+[\dA-Z]"
        
        ref_parenthesis = r" ?\(.*"+ref_whole+r".*?\)"    # e.x. (lorem Table 1 ipsum) or (Fig. 2.1)
        sent = re.sub(ref_parenthesis, "", sent, flags=re.IGNORECASE)

        if re.search(ref_whole, sent):
            continue
        
        sent, dehyphs = dehyphenate_string(sent, pg_num=pg_num)
        if dehyphs and log: 
            print(f"{'PG  :: d' + pg_num if pg_num else 'D'}e-hyphenated {dehyphs}")
        out += sent
    
    return out#.strip()

assert (res:=process_text((txt:="Gantry rotation time is usually about 0.5 seconds"))) == txt, res
assert (res:=process_text((txt:="The formula relating scan parameters for MDCT is shown in Fig. 1-1."))) == '', res
assert (res:=process_text((txt:="However, several general principles apply to all chest scans (TABLE 1-1)."))) == 'However, several general principles apply to all chest scans.', res
assert (res:=process_text((txt:="Non-Hodgkin’s"))) == txt, res
assert (res:=process_text((txt:="max-something"))) == txt, res
assert (res:=process_text((txt:="minimum-otherthing"))) == txt, res
assert (res:=process_text((txt:="highest-otherthing"))) == txt, res
assert (res:=process_text((txt:="e.g."))) == txt, res
assert (res:=process_text((txt:=".1"))) == txt, res

assert (res:=process_text((txt:="lorem)ipsum"))) == "lorem) ipsum", res
assert (res:=process_text((txt:="abc1"))) == "abc 1", res
assert (res:=process_text((txt:=".a "))) == ". a ", res
assert (res:=process_text((txt:=".a"))) == ".a", res
assert (res:=process_text((txt:="abcDef"))) == "abc Def", res
assert (res:=process_text((txt:="lorem(ipsum)"))) == "lorem (ipsum)", res
assert (res:=process_text((txt:="quickly,excellent"))) == "quickly, excellent", res

assert (res:=process_text((txt:="figs."))) == "figure", res
assert (res:=process_text((txt:="fig."))) == "figure", res
assert (res:=process_text((txt:="(fig. A)"))) == "", res
assert (res:=process_text((txt:="(fig. 3 description)"))) == "", res
assert (res:=process_text((txt:="(figure\n9. SAE)"))) == "", res
assert (res:=process_text((txt:="pre (fig. 1)."))) == "pre.", res
# assert (res:=process_text((txt:="Slice Thickness and Pitch (Table Excursion)"))) == txt, res

# %%
test_txt = """Because scan data are acquired continuously and volumetrically using spiral CT, scans may be reconstructed in any plane desired, if appropriate workstations are available. A variety of display techniques have been used for imaging the tho-rax. These include multiplanar reconstructions, three-dimensional shaded surface display or vol-ume rendering from an external perspective, or shaded surface or volume rendering from an internal (i.e., endoluminal) perspective, also known as virtual bronchoscopy.
# Multiplanar, two-dimensional reconstructions offer the advantage of being quickly performed and are sufficient for diagnosis in most cases in which a reformation is considered desirable. Subsequent chapters provide a number of examples of two-dimensional reconstructions. Three-dimensional techniques, such as shaded surface display and vol-ume rendering, can be valuable in selected cases, but they are time-consuming and require consider-able operator experience. These techniques are not commonly used in clinical chest imaging, with the exception of virtual bronchoscopy or airway imag-ing and specialized vascular imaging.
# Maximum- or minimum-intensity projection images representing a slab of three-dimensional data reconstructed from a volumetric data set may sometimes be useful in imaging pulmonary, airway, or vascular abnormalities."""
# test_txt="However, several general principles apply to all chest scans (TABLE 1-1)."
# test_txt="Gantry rotation time is usually about 0.5 seconds. The formula relating scan parameters for MDCT is shown in Fig. 1-1."

# %%
test_txt = """Spiral or helical computed tomography (CT)
allows the entire chest to be easily imaged during a
single breath hold, with volumetric acquisition
and exact registration or overlapping of slices.
Two- and three-dimensional reformations may
be performed if desired. Because scanning is
rapid, contrast agents can be injected quickly,
excellent vascular opacification can be achieved,
and reduced volumes of contrast agent can be
used.
SPIRAL CT IN CHEST DIAGNOSIS
Multiple-detector CT (MDCT) scanners have
multiple parallel rows (e.g., 64, 16, or 4) of x-ray
detectors, although the number varies with the
machine.Generally speaking, MDCT scanners
with fewer rows (e.g., 16 or 4) are being replaced
with scanners having more rows (e.g., 64), but
this is an expensive and, therefore, gradual
process.
"""

print(process_text(test_txt, log=True))
# Out:
# Spiral or helical computed tomography (CT)
# allows the entire chest to be easily imaged during a
# single breath hold, with volumetric acquisition
# and exact registration or overlapping of slices.
# Two-and three-dimensional reformations may
# be performed if desired. Because scanning is
# rapid, contrast agents can be injected quickly,
# excellent vascular opacification can be achieved,
# and reduced volumes of contrast agent can be
# used.
# SPIRAL CT IN CHEST DIAGNOSIS
# Multiple-detector CT (MDCT) scanners have
# multiple parallel rows (e.g., 64, 16, or 4) of x-ray
# detectors, although the number varies with the
# machine. Generally speaking, MDCT scanners
# with fewer rows (e.g., 16 or 4) are being replaced
# with scanners having more rows (e.g., 64), but
# this is an expensive and, therefore, gradual
# process.

# %% [markdown]
# # processing pages

# %% [markdown]
# ## setup

# %%
# %matplotlib inline
fc = FileChooser(
    DATA,
    filter_pattern="*.pdf",
    title="Select PDF file to extract",
    layout=ipywidgets.Layout(width="100%"),
)
display(fc)
# Out:
# FileChooser(path='/Users/andychen2121/Downloads/Work/NLP/custom_medical_llm/book-scrape/scrape_out', filename=…

# %%
fname = Path(fc.selected)
# fname = Path('/home/bdrad/Documents/Vogel/book-scrape/scrape/Chest - Webb - Fundamentals of Body CT (4e).pdf')
assert fname.is_file()
print(f"File selected: [{fname.name}]({fname.as_uri()})")
# Out:
# File selected: [General - Mandell - Core Radiology (1e).pdf](file:///Users/andychen2121/Downloads/Work/NLP/Custom%20Medical%20LLM/General%20-%20Mandell%20-%20Core%20Radiology%20%281e%29.pdf)

# %%
pdf = pdfplumber.open(fname)
pdf.metadata
# Out:
# {'Title': 'Core Radiology',
#  'Author': 'Mandell, Jacob',
#  'Creator': 'Adobe InDesign CS6 (Windows)',
#  'ModDate': "D:20150603205821-04'00'",
#  'Trapped': 'False',
#  'Producer': 'Adobe PDF Library 10.0.1',
#  'CreationDate': "D:20130824134134+05'30'",
#  'EBX_PUBLISHER': 'Cambridge University Press',
#  'PXCViewerInfo': "PDF-XChange Viewer;2.5.312.1;Feb  9 2015;11:58:02;D:20150603205821-04'00'"}

# %%
def extract_chapters(fname: Path) -> List[int]:
    # - this works only iff the PDF has indexs (embedded Table of Contents)
    # - this lacks the final page of end of final chapter
    import fitz
    pdf = fitz.open(fname)

    chapters = []
    for lvl, title, pg in pdf.get_toc():
        if lvl != 1: continue
        # if re.search(r"chapter \d+", title, flags=re.IGNORECASE):
            # print(f"{title}\tPage: {pg}")
        chapters.append(pg-1)   # 0-indexed
    return chapters

# %%
class Config:
    # Chapters are zero-indexed, and final number is the last page of the final chapter
    chapters: List[int] = None

    def __init__(self, fname: Path):
        match fname.name:
            case "Chest - Elicker - HRCT of the Lungs 2e.pdf":
                self.chapters = [49, 62, 83, 104, 116, 129, 150, 166, 174, 199, 212, 221, 233, 247, 265, 274, 283, 296, 305]
            case "Chest - Felson - Principles of Chest Roentgenology (4e).pdf":
                self.chapters = [8,29,46,68,84,104,122,136,160,182,202,226] # TODO rest of chpts
            case "Chest - Webb - Fundamentals of Body CT (4e).pdf":
                self.chapters = [6,12,26,49,73,94,134,151,176,188,214,225,241,250,278,290,323,340,349,363,370,]
            case "General - Weissleder - Primer of Diagnostic Imaging (5e).pdf":
                self.chapters = [13, 84, 127, 216, 280, 365, 439, 474, 521, 545, 587, 649, 692, 702, 759]
            case "General - Mandell - Core Radiology (1e).pdf":
                self.chapters = [12, 98, 168, 212, 357, 475, 564, 603, 669, 705, 752, 849, 874]
            case _:
                extract = extract_chapters(fname)
                if extract:
                    print("Chapters not found, extracted from PDF index (this will probably be off!):")
                    print(extract)
                    self.chapters = extract
                else:
                    print("Chapters not found and are un-extractable, please manually enter them in the config file")
                    raise KeyError
            
    def chapter_range(self):
        return list(zip(self.chapters, self.chapters[1:]))

    def contained_chapter(self, pg_num, chapter_range=None):
        chapter_range = chapter_range or self.chapter_range()
        for i, (start, end) in enumerate(chapter_range):
            if (start or float("-inf")) <= pg_num < (end or float("inf")):
                return i
        return None

config = Config(fname)
# config.chapter_range()

# %% [markdown]
# ### font cleaning

# %%
import pdfplumber
from pdfplumber.page import Page

pdf = pdfplumber.open(fname, laparams={"detect_vertical": False}).pages

start, end = config.chapter_range()[0]
pages = pdf[start:end]
pg = pages[2]
im = pg.to_image(resolution=123)
# im.draw_rects(pg.textboxhorizontals)
im = im.annotated

# %%
round_to_nearest_k: callable = lambda number, k: round(number * k) / k
assert round_to_nearest_k(1.3, 4) == 1.25
assert round_to_nearest_k(1.2, 4) == 1.25

# %%
# FFIOJI+Univers-CondensedBold => Univers
# UMTALE+JansonText-Roman => JansonText
inner_font = r'^([A-Z]+)\+(\w+?)-(\w+?)$'
def clean_fontstr(font: str):
    return re.sub(inner_font, r'\2', font) if re.search(inner_font, font) else font 

def clean_fonts(fonts: List[Tuple[str, float]]) -> Set[Tuple[str, float]]:
    if not fonts: return fonts
    return set([(clean_fontstr(f), round_to_nearest_k(s, k=4)) for f,s in fonts if f])
    
fonts=[[ "UMTALE+JansonText-Roman", 10.0 ], [ "PSFMKZ+JansonText-Italic", 10.0 ], [ "FFIOJI+Univers-CondensedBold", 10.0 ], [ "UMTALE+JansonText-Roman", 12.0 ]]
print(clean_fonts(fonts))
# Out:
# {('Univers', 10.0), ('JansonText', 12.0), ('JansonText', 10.0)}

# %%
from collections import Counter

def extract_fonts(pg: Page, k=4) -> List[Tuple[str, float]]:
    count = Counter()
    for ch in pg.chars:
        # out.add((ch['fontname'], ch['size']))
        name, size = ch['fontname'], ch['size']
        size = round_to_nearest_k(size, k=k) if round else size
        count[(name, size)] += 1

    out = [(clean_fontstr(fname), fsize) for (fname, fsize), _cnt in count.most_common()]
    
    # remove duplicates, but maintain ordering
    dedup = []
    seen = set()
    for fname,fsize in out:
        if (fname, fsize) not in seen:
            seen.add((fname, fsize))
            dedup.append((fname, fsize))
    return dedup

extract_fonts(pg)
# Out:
# [('UHEZNZ+Calibri', 12.0),
#  ('UHEZNZ+Calibri', 10.0),
#  ('Calibri', 14.0),
#  ('Calibri', 12.0),
#  ('TwCenMT', 11.0),
#  ('ZFMOFP+SymbolMT', 12.0),
#  ('PFPQVJ+Calibri', 12.0),
#  ('PFPQVJ+Calibri', 10.0)]

# %%
def compact_json(s):
    # % See appendix for example
    # Remove leading and tRailing whitespace within JSON objects
    s = re.sub(r'{\s+', '{ ', s)
    s = re.sub(r'\s+}', ' }', s)
    
    # Remove whitespace after commas within JSON arrays
    s = re.sub(r',\s+', ', ', s)
    
    # Remove leading and trailing whitespace within JSON arrays
    s = re.sub(r'\[\s+', '[ ', s)
    s = re.sub(r'\s+\]', ' ]', s)
    
    s = re.sub(r' ("body_font")', r'\n    \1', s)
    s = re.sub(r'( },) ({)', r'\1\n  \2', s)
    return s

# %% [markdown]
# ## layout parser
#
# [detectron2 config](https://detectron2.readthedocs.io/en/latest/modules/config.html#yaml-config-references)

# %%
pip install 'git+https://github.com/facebookresearch/detectron2.git@v0.4#egg=detectron2'
# Out:
# Collecting detectron2
#   Cloning https://github.com/facebookresearch/detectron2.git (to revision v0.4) to /private/var/folders/b_/fy9dn1455tv05c9ybjqsbp900000gn/T/pip-install-3gh_7szr/detectron2_751aee4b2c624d6a848f0b96765a0886
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/b_/fy9dn1455tv05c9ybjqsbp900000gn/T/pip-install-3gh_7szr/detectron2_751aee4b2c624d6a848f0b96765a0886
#   Running command git checkout -q 4aca4bdaa9ad48b8e91d7520e0d0815bb8ca0fb1
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 4aca4bdaa9ad48b8e91d7520e0d0815bb8ca0fb1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: termcolor>=1.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (2.3.0)
# Requirement already satisfied: Pillow>=7.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (9.4.0)
# Requirement already satisfied: yacs>=0.1.6 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (0.1.8)
# Requirement already satisfied: tabulate in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (0.9.0)
# Requirement already satisfied: cloudpickle in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (2.2.1)
# Requirement already satisfied: matplotlib in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (3.7.2)
# Requirement already satisfied: tqdm>4.29.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (4.65.0)
# Requirement already satisfied: tensorboard in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (2.14.1)
# Requirement already satisfied: fvcore<0.1.4,>=0.1.3 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (0.1.3.post20210317)
# Requirement already satisfied: iopath>=0.1.2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (0.1.10)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (2.0.7)
# Requirement already satisfied: future in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (0.18.3)
# Requirement already satisfied: pydot in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (1.4.2)
# Requirement already satisfied: omegaconf>=2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from detectron2) (2.3.0)
# Requirement already satisfied: numpy in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from fvcore<0.1.4,>=0.1.3->detectron2) (1.25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from fvcore<0.1.4,>=0.1.3->detectron2) (6.0)
# Requirement already satisfied: typing-extensions in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from iopath>=0.1.2->detectron2) (4.7.1)
# Requirement already satisfied: portalocker in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from iopath>=0.1.2->detectron2) (2.7.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from omegaconf>=2->detectron2) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (23.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from matplotlib->detectron2) (2.8.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (3.5)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (4.24.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (67.8.0)
# Requirement already satisfied: six>1.9 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from tensorboard->detectron2) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/andychen2121/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (3.2.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
def show(im, resolution=123, figsize=(10,10)):
    plt.figure(figsize=figsize, dpi=resolution)
    plt.axis("off")
    plt.imshow(im)
    plt.show()

# %%
model = None
del model
model = lp.models.Detectron2LayoutModel(
    # 'lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
    'lp://PubLayNet/mask_rcnn_X_101_32x8d_FPN_3x/config',
    # extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.9],
    # extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.77],
    # extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.72],
    extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.7],
    # extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.65],
    label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"}
)

# %%
from layoutparser.elements import Layout, Interval
from pdfplumber.page import Page
from pdfplumber.display import PageImage

def get_labels(im, return_split_idx=False, pad=0.05) -> Layout:
    if type(im) is PageImage:
        im = im.annotated
    
    w,h = im.size
    
    layout = model.detect(im) # Detect the layout of the input image
    # print(layout)
    
    text_blocks: Layout = lp.Layout([b for b in layout if b.type in ('Text', 'Title')]) 
    nontext_blocks: Layout = lp.Layout([b for b in layout if b.type in ('Figure', 'Table')])
    
    # As there could be text region detected inside the figure region, we just drop them:
    text_blocks: Layout = lp.Layout([b for b in text_blocks if not any(b.is_in(b_fig, center=True) for b_fig in nontext_blocks)])

    # canvas_height=h, canvas_width=w
    left_interval: Interval = lp.Interval(0, w/2*(1.0+pad), axis='x').put_on_canvas(im)

    left_blocks = text_blocks.filter_by(left_interval, center=True)
    right_blocks = [b for b in text_blocks if b not in left_blocks]

    sort_key = lambda b: b.coordinates[1]
    left_blocks = sorted(left_blocks, key=sort_key)
    right_blocks = sorted(right_blocks, key=sort_key)
    text_blocks = [b.set(id=idx) for idx, b in enumerate(left_blocks + right_blocks)]
    
    for i, b in enumerate(text_blocks):
        for c in text_blocks[:i] + text_blocks[i+1:]:   # get all but b
            if b.is_in(c, center=True):
                b = b.set(parent=c.id)
                print(f"%%% Text block {b.id} is inside {b.parent} -- skipping")

    if return_split_idx:
        return text_blocks, len(left_blocks)
    else:
        return text_blocks


pg = pages[4]
im = pg.to_image(resolution=123).annotated
sorted_boxes = get_labels(im)

lp.draw_box(im, sorted_boxes, box_width=3, show_element_id=True)
# Out:
# /Users/andychen2121/anaconda3/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1682343668887/work/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# <PIL.Image.Image image mode=RGB size=1061x1337>

# %% [markdown]
# # experimenting with image extractor

# %%
from layoutparser.elements import Layout, Interval
from pdfplumber.page import Page
from pdfplumber.display import PageImage

def get_images(im, return_split_idx=False, pad=0.05) -> Layout:
    if type(im) is PageImage:
        im = im.annotated
    
    w,h = im.size
    
    layout = model.detect(im) # Detect the layout of the input image
    # print(layout)
    
    nontext_blocks: Layout = lp.Layout([b for b in layout if b.type in ('Figure', 'Table')])
    
    for i, b in enumerate(nontext_blocks):
        for c in nontext_blocks[:i] + nontext_blocks[i+1:]:   # get all but b
            if b.is_in(c, center=True):
                b = b.set(parent=c.id)
                print(f"%%% Text block {b.id} is inside {b.parent} -- skipping")

    if return_split_idx:
        return nontext_blocks, len(left_blocks)
    else:
        return nontext_blocks


pg = pages[4]
im = pg.to_image(resolution=123).annotated
sorted_boxes = get_images(im)

lp.draw_box(im, sorted_boxes, box_width=3, show_element_id=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1061x1337>

# %% [markdown]
# ## tracker

# %%
from collections import defaultdict

class ChapterEntry(defaultdict):
    
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__
    
    # body_font = set()
    # header_font = set()
    # label_end = label_start = -1
    # pg_end = pg_start = pg_curr = -1

TOK_LABEL_END = '[LABEL_END]'
TOK_STARTUP = '[STARTUP]'
TOK_FONTBREAK = '[FONTBREAK]'
TOK_NOFONT = ('[NOFONT]', -1)

# %%
# todo better way to manage these -- write to config file?
font_blacklist: Set[Tuple[str, float]] = set()
font_bodies: Set[Tuple[str, float]] = set()
font_headers: Set[Tuple[str, float]] = set()

# %%
class ChapterTracker:
    skip_interruping_header = True
    skip_font_label_mismatch = False    # issue: causes skip_interrupting_header to be ignored
    assert skip_interruping_header and skip_font_label_mismatch is False
    multifont_new_entry = False         # not implemented
    close_rstrip = True
    clean_merge = False  # ensure there is a single space between existing text and the new entry
    
    early_exit_txts = ('SUGGESTED READING')
    
    modes = {'startup', 'header', 'body'}
    types = {'Title', 'Text', 'Figure', 'Table'}
    
    def  __init__(self, mode='startup', entries=None) -> None:
        self.mode = mode
        assert self.mode in self.modes
        self.entries: List[ChapterEntry] = entries or []    # having the argument as a list mutates it; copies chapter-to-chapter entries.
        self.header = self.body = ''
        self.body_font = set()
        self.header_font = set()
        self.label_end = self.label_start = -1
        self.pg_end = self.pg_start = self.pg_curr = -1
        self.images = []
        
    # @property
    # def current_font(self):
    #     return self.header_font if self.mode == 'header' else self.body_font
        
    def close(self):
        if self.body == self.header == '':
            return
        if self.mode != 'body':
            print(f"### Closed while in {self.mode} -- we should only close when in `body` mode")
        if self.close_rstrip:
            self.header, self.body = self.header.rstrip(), self.body.rstrip()
        self.header_font, self.body_font = self.header_font or [TOK_NOFONT], self.body_font or [TOK_NOFONT]
        self.entries.append(dict(
                label_range=[self.label_start, self.label_end], pg_range=[self.pg_start, self.pg_end], 
                header_font=self.header_font, header=self.header, body_font=self.body_font, body=self.body,
                images = self.images)
            )
        self.__init__(entries=self.entries)
        
    def get_entries(self) -> List[ChapterEntry]:
        self.close()
        return self.entries
    
    def font_log(self, fonts: List[Tuple[str, float]], mode, k=4):
        inner_font = r'^([A-Z]+)\+(\w+?)-(\w+?)$'
        fonts = [((re.sub(inner_font, r'\2', font) if re.search(inner_font, font) else inner_font), round_to_nearest_k(size, k)) for font, size in fonts]
        
        if mode == 'header':
            font_headers.union(fonts)
        else:
            font_bodies.union(fonts)
    
    def font_category(self, fonts: List[Tuple[str, float]]) -> str:
        # TODO track avg font size for each
        cnt_header = sum([font in font_headers for font in fonts])
        cnt_body = sum([font in font_bodies for font in fonts])
        return 'body' if cnt_body > cnt_header else 'header'
        
    def font_parse(self, label_type, fonts: List[Tuple[str, float]], txt) -> bool:
        assert label_type in self.types
        label_mode = 'header' if label_type == 'Title' else 'body'
        
        if len(fonts)>1 and self.multifont_new_entry:   # and any([font in others for font in fonts])
            raise NotImplementedError
            return False
        if not (self.header_font if self.mode == 'header' else self.body_font):
        # if not self.current_font: # ! this line breaks 
            if label_mode=='header':
                self.header_font = set([max(fonts, key=lambda f: f[1])]) # largest font
            else:
                self.body_font = set([fonts[0]])   # most frequent font
            return True
        else:
            if self.font_category(fonts) != label_mode:
                if self.skip_font_label_mismatch:
                    self.close()
                    self.body_font = set(fonts)
                    self.header_font = set(fonts)
                    self.header = TOK_FONTBREAK
                    self.body = txt
                    self.mode = "body"
                return False
            if label_mode=='header':
                self.header_font.add(max(fonts, key=lambda f: f[1]))
            else:
                self.body_font.add(fonts[0])
        
        return True

    def add_img(self, img, label_type, ref):
        assert label_type in self.types
        if not img: return
        img.save(ref)
        print(f'saved at {ref}')
        self.images.append(ref)
    
    def add_txt(self, txt: str, label_type: str, fonts: List[Tuple[str, float]], pg_num: int, label_num: int):
        assert label_type in self.types
        if not txt: return
        txt = process_text(txt) # pg_num=pg_num
        if not txt: return
        
        if any([font in font_blacklist for font in fonts]):
            print(f'!!! blacklisted font, skipping `{txt}`')
            return
        

        log_font_mode: str = None
        # mode to which the font will be logged to
        # only set if confident the label correctly matches, i.e. we are extending the entry
        
        if txt in self.early_exit_txts:
            self.close()
            return
        
        if label_type == "Title":
            if self.mode == "header":
                if self.clean_merge:
                    self.header = self.header.rstrip() + " " + txt.lstrip()
                else:
                    self.header += txt
            else:
                if not ends_with(self.body) and self.skip_interruping_header and pg_num == self.pg_curr:
                    print(f'>>> interrupting header, skipping `{txt}`')
                    return
                self.close()
                self.header = txt
                self.mode = "header"
            log_font_mode = "header"

        elif label_type == "Text":
            if txt.endswith(TOK_SENTENCE_TERMS):
                # txt += (f"\n {TOK_LABEL_END} \n" if TOK_LABEL_END else '\n')
                txt += '\n'
            if self.mode == 'header':
                self.body = txt
                log_font_mode = "body"
            else:
                if self.mode == "body":
                    self.log_font_mode = "body"
                if self.mode == "startup" and self.header == '':
                    self.header = TOK_STARTUP
                if not re.search(r"\s+$", self.body) and not re.search(r"^\s+", txt):
                    txt = " " + txt # insert space if existing body doesn't end with whitespace
                if self.clean_merge:
                    self.body = self.body.rstrip() + " " + txt.lstrip()
                else:
                    self.body += txt
            self.mode = "body"
        
        if self.pg_curr < pg_num:
            self.pg_curr = pg_num
            
        if self.pg_start < 0:
            self.pg_start = pg_num
        if self.label_start < 0:
            self.label_start = label_num
        
        self.pg_end, self.label_end = pg_num, label_num
        
        if not self.font_parse(label_type, fonts, txt):
            # this works now, but should be placed above
            # to raise an error when the current font isn't in [body/header]_font 
            return
        if log_font_mode:
            self.font_log(fonts, log_font_mode)

# %% [markdown]
# ## Main

# %%
from layoutparser.elements import TextBlock
from tqdm.notebook import tqdm
import json

def process_file_tracker(
    fname: Path,
    # pad=0.010,
    pad=0.0075,
    # pad=0.005,
    resolution=123,
    laparams=dict(detect_vertical=False)
    # laparams=dict(detect_vertical=False, word_margin=0.08)    # this doesn't cause any difference?
):
    assert 0<=pad<1
    
    pdf = pdfplumber.open(fname, laparams=laparams).pages
    
    outdir = Path("scrape_out")
    outdir /= fname.stem
    outdir.mkdir(parents=True, exist_ok=True)

    imgdir = Path(f"scrape_out/{fname.stem}/images")
    imgdir.mkdir(parents=True, exist_ok=True)
    image_count = 0

    config = Config(fname)
    # chapters = [config.chapter_range()[0]]
    chapters = config.chapter_range()
    for i, ch in enumerate(chapters,1):
        print(f"Processing ch{i}")
        start, end = ch
        pages = pdf[start:end]
        tracker = ChapterTracker()
        
        progress = tqdm(pages)
        for pg in progress:
            pg_num = pg.page_number
            im = pg.to_image(resolution=resolution).annotated
            w_im,h_im = im.size
            w_pg,h_pg = pg.width,pg.height
            w_ratio,h_ratio = w_pg/w_im,h_pg/h_im

            # Text extractor
            # TODO: pass coordinates as well ?
            labels = get_labels(im)
            for label_num, label in enumerate(labels):
                # print(label)
                label: TextBlock
                if label.parent is not None: 
                    print(f"%%% Text block {label.id} is inside {label.parent} -- skipping")
                    continue
                pad_x, pad_y = pad*w_im, pad*h_im
                label = label.pad(left=pad_x, right=pad_x, top=pad_y, bottom=pad_y)
                x0,y0,x1,y1 = label.coordinates
                x0,x1 = x0*w_ratio, x1*w_ratio
                y0,y1 = y0*h_ratio, y1*h_ratio
                
                kind = label.type
                assert kind in ("Text", "Title")
                
                area = pg.within_bbox((x0,y0,x1,y1))
                fonts = extract_fonts(area)
                txt = area.extract_text()
                tracker.add_txt(txt, kind, fonts, pg_num, label_num)

            # Image extractor
            # TODO: pass coordinates as well ?
            images = get_images(im)
            for image_num, image in enumerate(images):
                image: TextBlock
                if image.parent is not None: 
                    print(f"%%% Image block {image.id} is inside {image.parent} -- skipping")
                    continue
                x0,y0,x1,y1 = image.coordinates
                x0,x1 = x0*w_ratio, x1*w_ratio
                y0,y1 = y0*h_ratio, y1*h_ratio
                
                kind = image.type
                assert kind in ('Figure', 'Table')

                area = pg.within_bbox((x0,y0,x1,y1))
                img = area.crop((x0,y0,x1,y1)).to_image()
                tracker.add_img(img, kind, f"{outdir}/images/{image_count}.png")
                image_count += 1
                
                
        tracker.close()
        
        with open(outdir / f"ch{i}_tracker.json", "w", encoding="utf8") as f:
            print(f"*** saving to {f.name}")
            data = tracker.get_entries()
            data = [{k: (list(v) if type(v) is set else v) for k,v in entry.items()} for entry in data] # json-ify: tuples -> lists
            
            # json.dump(data, f, indent=2, ensure_ascii=False)
            s = json.dumps(data, indent=2, ensure_ascii=False)
            s = compact_json(s)
            f.write(s)

# %%
process_file_tracker(fname)
# Out:
# Processing ch1
#   0%|          | 0/86 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/0.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1.png
# >>> interrupting header, skipping `Lobar atelectasis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/2.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/3.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/4.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/5.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/6.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/7.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/8.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/9.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/10.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/11.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/12.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/13.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/14.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/15.png
# %%% Text block 0 is inside 1 -- skipping
# %%% Text block 1 is inside 0 -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/16.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/17.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/18.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/19.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/20.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/21.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/22.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/23.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/24.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/25.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/26.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/27.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/28.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/29.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/30.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/31.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/32.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/33.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/34.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/35.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/36.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/37.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/38.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/39.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/40.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/41.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/42.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/43.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/44.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/45.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/46.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/47.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/48.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/49.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/50.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/51.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/52.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/53.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/54.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/55.png
# >>> interrupting header, skipping `solitary pulmonary nodule`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/56.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/57.png
# %%% Text block 4 is inside 3 -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/58.png
# >>> interrupting header, skipping `Segmental or lobar atelectasis`
# >>> interrupting header, skipping `Consolidation`
# >>> interrupting header, skipping `Hilar mass`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/59.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/60.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/61.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/62.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/63.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/64.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/65.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/66.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/67.png
# %%% Text block 0 is inside 1 -- skipping
# %%% Text block 1 is inside 0 -- skipping
# >>> interrupting header, skipping `Pulmonary hypertension associated with hypoxemic lung disease – WHO group 3, precapillary`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/68.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/69.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/70.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/71.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/72.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/73.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/74.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/75.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/76.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/77.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/78.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/79.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/80.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/81.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/82.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/83.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/84.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/85.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/86.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/87.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/88.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/89.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/90.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/91.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/92.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/93.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/94.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/95.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/96.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/97.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/98.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/99.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/100.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/101.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/102.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/103.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/104.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/105.png
# >>> interrupting header, skipping `Morgagni hernia`
# >>> interrupting header, skipping `Middle mediastinal mass`
# >>> interrupting header, skipping `Ascending aortic or aortic arch aneurysm`
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/106.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/107.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/108.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/109.png
# >>> interrupting header, skipping `Relapsing polychondritis`
# >>> interrupting header, skipping `Tracheobronchopathia osteochondroplastica (TPO)`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/110.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/111.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/112.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/113.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/114.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/115.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/116.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/117.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/118.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/119.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/120.png
# >>> interrupting header, skipping `Benign endobronchial lesions`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/121.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/122.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/123.png
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch1_tracker.json
# Processing ch2
#   0%|          | 0/70 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/124.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/125.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/126.png
# ### Failed to dehyphenate word: in-(left
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/127.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/128.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/129.png
# >>> interrupting header, skipping `Malignant hepatic masses`
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/130.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/131.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/132.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/133.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/134.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/135.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/136.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/137.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/138.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/139.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/140.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/141.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/142.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/143.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/144.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/145.png
# >>> interrupting header, skipping `Introduction to Mrc P`
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/146.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/147.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/148.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/149.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/150.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/151.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/152.png
# >>> interrupting header, skipping `causes Zollinger Ellison syndrome`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/153.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/154.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/155.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/156.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/157.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/158.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/159.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/160.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/161.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/162.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/163.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/164.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/165.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/166.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/167.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/168.png
# >>> interrupting header, skipping `Achalasia`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/169.png
# >>> interrupting header, skipping `Zenker diverticulum`
# >>> interrupting header, skipping `Killian–Jamieson (KJ) diverticulum`
# >>> interrupting header, skipping `Pseudodiverticulosis`
# >>> interrupting header, skipping `Miscellaneous esophageal disorders`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/170.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/171.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/172.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/173.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/174.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/175.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/176.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/177.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/178.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/179.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/180.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/181.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/182.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/183.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/184.png
# >>> interrupting header, skipping `Epiploic appendagitis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/185.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/186.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/187.png
# >>> interrupting header, skipping `Mesenteric edema`
# >>> interrupting header, skipping `Mesenteric inflammation`
# >>> interrupting header, skipping `Intraabdominal hemorrhage`
# >>> interrupting header, skipping `Neoplastic infiltration`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/188.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/189.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/190.png
# >>> interrupting header, skipping `Small Bowel:`
# ### Failed to dehyphenate word: m.-L.F.,
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch2_tracker.json
# Processing ch3
#   0%|          | 0/44 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/191.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/192.png
# ### Failed to dehyphenate word: HII‘_-_.|__H
# ### Failed to dehyphenate word: __I|_I“_|_1l|__r___I_II-_r-‘__I|_mFJIIIIIWIHII‘
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/193.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/194.png
# >>> interrupting header, skipping `biochemical approach to adrenal lesions`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/195.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/196.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/197.png
# >>> interrupting header, skipping `Adrenal calcification`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/198.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/199.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/200.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/201.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/202.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/203.png
# >>> interrupting header, skipping `renal cysts and cystic renal masses`
# >>> interrupting header, skipping `Renal sinus cyst`
# >>> interrupting header, skipping `Hyperdense cyst`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/204.png
# >>> interrupting header, skipping `Pyelonephritis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/205.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/206.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/207.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/208.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/209.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/210.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/211.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/212.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/213.png
# ### Failed to dehyphenate word: (OIS)-American
# >>> interrupting header, skipping `Page kidney`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/214.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/215.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/216.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/217.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/218.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/219.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/220.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/221.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/222.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/223.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/224.png
# >>> interrupting header, skipping `Urethral stricture`
# >>> interrupting header, skipping `Urethral trauma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/225.png
# >>> interrupting header, skipping `Urethral diverticulum`
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/226.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/227.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/228.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/229.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/230.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/231.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/232.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/233.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/234.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/235.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/236.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/237.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/238.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/239.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/240.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/241.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/242.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/243.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/244.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/245.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/246.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/247.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/248.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/249.png
# ### Failed to dehyphenate word: CT—10-minute
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch3_tracker.json
# Processing ch4
#   0%|          | 0/145 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/250.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/251.png
# >>> interrupting header, skipping `cerebral edema`
# >>> interrupting header, skipping `Vasogenic edema`
# >>> interrupting header, skipping `Interstitial edema`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/252.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/253.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/254.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/255.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/256.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/257.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/258.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/259.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/260.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/261.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/262.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/263.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/264.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/265.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/266.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/267.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/268.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/269.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/270.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/271.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/272.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/273.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/274.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/275.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/276.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/277.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/278.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/279.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/280.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/281.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/282.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/283.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/284.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/285.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/286.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/287.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/288.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/289.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/290.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/291.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/292.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/293.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/294.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/295.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/296.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/297.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/298.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/299.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/300.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/301.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/302.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/303.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/304.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/305.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/306.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/307.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/308.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/309.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/310.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/311.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/312.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/313.png
# >>> interrupting header, skipping `Persistent carotid–basilar connections`
# >>> interrupting header, skipping `Persistent trigeminal artery`
# >>> interrupting header, skipping `Less common carotid to basilar connections`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/314.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/315.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/316.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/317.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/318.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/319.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/320.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/321.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/322.png
# %%% Text block 0 is inside 1 -- skipping
# %%% Text block 1 is inside 0 -- skipping
# >>> interrupting header, skipping `Early subacute infarct (1.5 days–5 days)`
# >>> interrupting header, skipping `Late subacute infarct (5 days–2 weeks)`
# >>> interrupting header, skipping `Chronic infarct`
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/323.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/324.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/325.png
# >>> interrupting header, skipping `Capillary telangiectasia`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/326.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/327.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/328.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/329.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/330.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/331.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/332.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/333.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/334.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/335.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/336.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/337.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/338.png
# >>> interrupting header, skipping `Idiopathic/autoimmune/inflammatory white matter disease`
# >>> interrupting header, skipping `Multiple sclerosis (MS)`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/339.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/340.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/341.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/342.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/343.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/344.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/345.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/346.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/347.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/348.png
# %%% Text block 3 is inside 2 -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/349.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/350.png
# >>> interrupting header, skipping `neck infections and inflammation`
# >>> interrupting header, skipping `Ludwig angina`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/351.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/352.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/353.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/354.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/355.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/356.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/357.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/358.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/359.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/360.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/361.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/362.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/363.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/364.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/365.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/366.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/367.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/368.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/369.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/370.png
# >>> interrupting header, skipping `Esthesioneuroblastoma`
# >>> interrupting header, skipping `Squamous cell carcinoma`
# >>> interrupting header, skipping `Adenoid cystic carcinoma`
# >>> interrupting header, skipping `Rhabdomyosarcoma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/371.png
# >>> interrupting header, skipping `Congenital EAC stenosis, hypoplasia and atresia`
# >>> interrupting header, skipping `Acute external otitis`
# >>> interrupting header, skipping `Keratosis obturans`
# >>> interrupting header, skipping `Middle ear`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/372.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/373.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/374.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/375.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/376.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/377.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/378.png
# >>> interrupting header, skipping `Cochlear dysplasia (Mondini deformity)`
# >>> interrupting header, skipping `Enlarged vestibular aqueduct syndrome`
# >>> interrupting header, skipping `Otospongiosis (otosclerosis)`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/379.png
# >>> interrupting header, skipping `Cholesterol cyst (cholesterol granuloma)`
# >>> interrupting header, skipping `Apical petrositis (petrous apicitis)`
# >>> interrupting header, skipping `Congenital cholesteatoma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/380.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/381.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/382.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/383.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/384.png
# >>> interrupting header, skipping `Preseptal infection`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/385.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/386.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/387.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/388.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/389.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/390.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/391.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/392.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/393.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/394.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/395.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/396.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/397.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/398.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/399.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/400.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/401.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/402.png
# >>> interrupting header, skipping `Level I`
# >>> interrupting header, skipping `Level II`
# >>> interrupting header, skipping `Level III`
# >>> interrupting header, skipping `Level IV`
# >>> interrupting header, skipping `Level VII`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/403.png
# >>> interrupting header, skipping `Astrocytoma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/404.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/405.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/406.png
# >>> interrupting header, skipping `Degenerative disease`
# >>> interrupting header, skipping `Vertebral body/epidural metastasis`
# >>> interrupting header, skipping `Discitis/osteomyelitis`
# >>> interrupting header, skipping `Hemangioma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/407.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/408.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/409.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/410.png
# >>> interrupting header, skipping `Ossifi cation of the posterior longitudinal ligament (OPLL)`
# >>> interrupting header, skipping `Postoperative spine`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/411.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/412.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/413.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/414.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/415.png
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch4_tracker.json
# Processing ch5
#   0%|          | 0/118 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/416.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/417.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/418.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/419.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/420.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/421.png
# >>> interrupting header, skipping `Erosive osteoarthritis of the hands`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/422.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/423.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/424.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/425.png
# >>> interrupting header, skipping `Rheumatoid arthritis in the elbow`
# >>> interrupting header, skipping `Inflammatory bowel disease`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/426.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/427.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/428.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/429.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/430.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/431.png
# >>> interrupting header, skipping `b: bone creation`
# >>> interrupting header, skipping `E: Erosions`
# >>> interrupting header, skipping `s: soft-tissue swelling`
# >>> interrupting header, skipping `Very very aggressive: Codman triangle`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/432.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/433.png
# >>> interrupting header, skipping `Location within bone`
# >>> interrupting header, skipping `Benign and incidental: Osteoma`
# >>> interrupting header, skipping `Benign: Melorheostosis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/434.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/435.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/436.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/437.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/438.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/439.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/440.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/441.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/442.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/443.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/444.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/445.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/446.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/447.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/448.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/449.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/450.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/451.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/452.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/453.png
# >>> interrupting header, skipping `Malignant: Ewing sarcoma`
# >>> interrupting header, skipping `giant cell tumor:`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/454.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/455.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/456.png
# >>> interrupting header, skipping `Benign: Aneurysmal bone cyst (ABC)`
# >>> interrupting header, skipping `Malignant: Adamantinoma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/457.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/458.png
# >>> interrupting header, skipping `Hematogenous osteomyelitis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/459.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/460.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/461.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/462.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/463.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/464.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/465.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/466.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/467.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/468.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/469.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/470.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/471.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/472.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/473.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/474.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/475.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/476.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/477.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/478.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/479.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/480.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/481.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/482.png
# >>> interrupting header, skipping `A Boehler angle <20˚ is diagnostic of a calcaneal fracture.
# A normal Boehler angle (20−40˚) does not exclude a calcaneal fracture.`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/483.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/484.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/485.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/486.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/487.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/488.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/489.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/490.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/491.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/492.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/493.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/494.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/495.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/496.png
# ...
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/855.png
# >>> interrupting header, skipping `Percutaneous gastrostomy indications and technique`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/856.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/857.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/858.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/859.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/860.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/861.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/862.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/863.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/864.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/865.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/866.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/867.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/868.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/869.png
# >>> interrupting header, skipping `Neurogenic thoracic outlet syndrome`
# >>> interrupting header, skipping `Subclavian artery compression`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/870.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/871.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/872.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/873.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/874.png
# >>> interrupting header, skipping `Venous stenosis of surgical dialysis access`
# >>> interrupting header, skipping `Thrombosis of surgical dialysis access`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/875.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/876.png
# ### Failed to dehyphenate word: J.-m.
# ### Failed to dehyphenate word: J.-m.
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch10_tracker.json
# Processing ch11
#   0%|          | 0/97 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/877.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/878.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/879.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/880.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/881.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/882.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/883.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/884.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/885.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/886.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/887.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/888.png
# >>> interrupting header, skipping `Innominate artery syndrome`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/889.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/890.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/891.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/892.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/893.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/894.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/895.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/896.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/897.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/898.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/899.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/900.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/901.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/902.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/903.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/904.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/905.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/906.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/907.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/908.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/909.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/910.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/911.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/912.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/913.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/914.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/915.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/916.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/917.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/918.png
# >>> interrupting header, skipping `Gastric atresia`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/919.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/920.png
# %%% Text block 1 is inside 2 -- skipping
# %%% Text block 2 is inside 1 -- skipping
# >>> interrupting header, skipping `Duodenal atresia, stenosis, and web`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/921.png
# %%% Text block 3 is inside 2 -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/922.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/923.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/924.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/925.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/926.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/927.png
# >>> interrupting header, skipping `Biliary atresia`
# >>> interrupting header, skipping `Neonatal hepatitis`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/928.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/929.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/930.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/931.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/932.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/933.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/934.png
# >>> interrupting header, skipping `Metastatic disease`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/935.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/936.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/937.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/938.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/939.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/940.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/941.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/942.png
# >>> interrupting header, skipping `Wilms tumor`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/943.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/944.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/945.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/946.png
# >>> interrupting header, skipping `Multilocular cystic nephroma`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/947.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/948.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/949.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/950.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/951.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/952.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/953.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/954.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/955.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/956.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/957.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/958.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/959.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/960.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/961.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/962.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/963.png
# %%% Text block 1 is inside 2 -- skipping
# %%% Text block 2 is inside 1 -- skipping
# >>> interrupting header, skipping `Nonspecific (but frequently seen)`
# >>> interrupting header, skipping `Achondroplasia`
# >>> interrupting header, skipping `Thanatophoric dysplasia (lethal)`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/964.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/965.png
# >>> interrupting header, skipping `Hurlers`
# >>> interrupting header, skipping `Morquio`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/966.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/967.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/968.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/969.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/970.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/971.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/972.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/973.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/974.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/975.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/976.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/977.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/978.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/979.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/980.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/981.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/982.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/983.png
# >>> interrupting header, skipping `Prostaglandin therapy`
# >>> interrupting header, skipping `Infectious`
# >>> interrupting header, skipping `Metabolic`
# >>> interrupting header, skipping `Syndromic`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/984.png
# >>> interrupting header, skipping `congenital malformations`
# >>> interrupting header, skipping `Polymicrogyria`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/985.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/986.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/987.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/988.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/989.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/990.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/991.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/992.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/993.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/994.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/995.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/996.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/997.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/998.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/999.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1000.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1001.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1002.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1003.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1004.png
# >>> interrupting header, skipping `Pediatric Cardiac:`
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch11_tracker.json
# Processing ch12
#   0%|          | 0/25 [00:00<?, ?it/s]
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1005.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1006.png
# >>> interrupting header, skipping `Mild contrast reactions`
# >>> interrupting header, skipping `Moderate contrast reactions`
# >>> interrupting header, skipping `Severe contrast reactions`
# >>> interrupting header, skipping `Premedication to prevent contrast reaction`
# >>> interrupting header, skipping `Iodinated contrast and thyroid uptake`
# >>> interrupting header, skipping `Metformin and intravenous contrast`
# ### Failed to dehyphenate word: org/Quality-Safety/Resources/Contrast-manual,
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1007.png
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1008.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1009.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1010.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1011.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1012.png
# %%% Text block None is inside None -- skipping
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1013.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1014.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1015.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1016.png
# >>> interrupting header, skipping `T 1 and T 2`
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1017.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1018.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1019.png
# saved at scrape_out/General - Mandell - Core Radiology (1e)/images/1020.png
# *** saving to scrape_out/General - Mandell - Core Radiology (1e)/ch12_tracker.json

# %% [markdown]
# # post processing
#
# - everything we can't greedily use regex for
# - detect..
#     - conjugated words
#     - figures
#     - skipped/missing text
#     - out of order sentences
#     - duplicated sentences
# - for these capabilities, will need to log font size+family+relative position of each textbox
# - should also have some method to catch skipped boxes (i.e. those not recognized by layout parser OCR -- notably lists are buggy)

# %%
# TODO

# %% [markdown]
# # appendix

# %% [markdown]
# ## example snippets

# %% [markdown]
# ### extract fonts

# %%
box = sorted_boxes[1]
print(box)
x0,y0,x1,y1 = box.coordinates

w_im,h_im = im.size
w_pg,h_pg = pg.width,pg.height
w_ratio,h_ratio = w_pg/w_im,h_pg/h_im
pad=0.005
x0,x1 = (x0-pad*w_im)*w_ratio, (x1+pad*w_im)*w_ratio
y0,y1 = (y0-pad*h_im)*h_ratio, (y1+pad*h_im)*h_ratio

y1 *= 1

area = pg.within_bbox((x0,y0,x1,y1))
area_im = area.to_image(resolution=123).annotated
plt.imshow(area_im)
extract_fonts(area)
# Out:
# TextBlock(block=Rectangle(x_1=107.79412078857422, y_1=990.101806640625, x_2=240.0605926513672, y_2=1010.4228515625), text=None, id=1, type=Text, parent=None, next=None, score=0.7693758606910706)
# [('TwCenMT', 11.0)]

# %% [markdown]
# ### layout parser

# %%
import layoutparser as lp
import numpy as np

# block_A = lp.Rectangle(50, 50, 150, 150)
# block_B = lp.Rectangle(40, 60, 160, 30)
block_A = lp.Rectangle(40, 50, 150, 150) 
block_B = lp.Rectangle(40, 120, 140, 151)

lp.draw_box(np.ones((200,200,3), dtype='uint8')*255, [block_A, block_B])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
print(block_A.is_in(block_B))
print(block_B.is_in(block_A))
print(block_A.is_in(block_B, center=True))
print(block_B.is_in(block_A, center=True))
# Out:
# False
# False
# False
# True

# %% [markdown]
# ## unfinished/broken/abandoned code

# %% [markdown]
# ### overlap detection
#
# - current approach with layoutparser seems good enough
# - this 'manual' approach is  not done

# %%
# TODO finish this
import numpy as np
import matplotlib.pyplot as plt
from math import ceil,floor

def place(i,j,data,itm,center=False):
    h,w=itm.shape
    
    if center: 
        i-=h//2
        j-=w//2
    
    data[i:i+h,j:j+w]+=itm
    return data

def rm_overlap(rect0: List[int],rect1: List[int], favor=0, interp=0.66) -> Tuple[List[int], List[int]]:
    assert 0<=interp<=1
    
    x0,y0,x1,y1=rect0
    a0,b0,a1,b1=rect1
    
    # no overlap
    if x1<a0 or a1<x0 or y1<b0 or b1<y0:
        return rect0, rect1
    
    # boxes overlap in x, and y
    if not (x1<a0 or a1<x0) and not (y1<b0 or b1<y0):
        p,q=interp,1-interp
        
        if y0<b0<y1<b1:     # rect0 above rect1
            margin = y1-b0
            y1-=margin*(q if favor else p)
            b0+=margin*(p if favor else q)
            y1,b0=floor(y1),ceil(b0)            
        elif b0<y0<b1<y1:   # rect0 below rect1
            margin = b1-y0
            y0+=margin*(q if favor else p)
            b1-=margin*(p if favor else q)
            y0,b1=ceil(y0),floor(b1)
        else:
            print('** ignoring overlap case (contained)')
    
    # y0,b0=max(y0,0),max(b0,0)
    return [x0,y0,x1,y1], [a0,b0,a1,b1]
    

n = 14
data = np.zeros((n,n))

a_dim = (7,11)
a_off = (1,1)
a = np.ones(a_dim)/3.0
ax0,ay0 = a_off
ax1,ay1 = [a+i for a,i in zip(a_off,a.shape)]


b_dim = (5,8)
b_off = (6,2)
b = np.ones(b_dim)/2.0
bx0,by0 = b_off
bx1,by1 = [b+i for b,i in zip(b_off,b.shape)]

(ax0,ay0,ax1,ay1), (bx0,by0,bx1,by1) = rm_overlap((ax0,ay0,ax1,ay1), (bx0,by0,bx1,by1))
place(*a_off,data,a)
print(ax0,ay0,ax1,ay1)
place(*b_off,data,b)
print(bx0,by0,bx1,by1)

plt.imshow(data, interpolation='nearest');
# Out:
# ** ignoring overlap case (contained)
# 1 1 8 12
# 6 2 11 10

# %% [markdown]
# ### typing entry

# %%
from collections import defaultdict
from typing import TypedDict

class ChapterEntry(defaultdict):
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

    header_font: List[Tuple[str, float]]
    header: str
    body_font: List[Tuple[str, float]]
    body: str
    label_start: int
    label_end: int
    pg_start: int
    pg_end: int
# type FontPair = Tuple[str, float]     # need python 3.12

# %% [markdown]
# ## old code

# %% [markdown]
# ### `pdfplumber`

# %%
import pdfplumber

pdf = pdfplumber.open(fname, laparams={"detect_vertical": False}).pages

# %%
start, end = config.chapter_range()[0]
pages = pdf[start:end]
pg = pages[3]
pg.to_image(resolution=123).draw_rects(pg.textboxhorizontals).show()

# %%
# text = pg.extract_text()
# print(text)

words = pg.extract_words()
words = pg.extract_words(use_text_flow=True, x_tolerance=7, keep_blank_chars=True)
print(" ".join([w['text'] for w in words]))
# Out:
# Patterns of lobar atelectasis frontal schematic LUL RUL ~~ __ \‘ _ _& ~ ~~~‘I’ II _ % ~ %_ “ %_ \ \\\ lll\ " _ _ . _ \\ ’I ‘ \\ "\\\ II \\ Ik I I I I II \\“ ‘ § M §§ R,‘% \Q RML Q n Q u _ u*"“ u I O - _ II II I II I I I \\\ \\\ \\\ \\\\ In \‘ I \\\ I’ \’\\ ’ \\I’ \ I \\ \\\ \\ \“ LLL RLL right lung left lung RUL “‘I'll \“I,’ \‘ I _ “_ ‘ ‘ . \‘ ‘\ ‘\‘ _ \__W Iv \ \ \I II \‘ Flll " RML 4lll. lateral schematic LUL ‘\\ \:‘ ‘\' “ \\\‘ \\III‘ ‘ ‘‘\ ‘‘ ‘\‘ l|llll"| \\ K‘ \II \III \\\ ‘--|-"-"- \I ‘\lIll||lI \III II I I III II II IIIII IIII III III U I I ‘-I- I III Ill I I I It \ \\\,III \ ll II I I II RLL LLL right lung left lung •	 Each of the five lobes tends to collapse in a predictable direction, as shown above. 4

# %%
from layoutparser.elements import TextBlock

def process_page_DNN(pg: Page, pad=0.005, resolution=123):
    assert 0<=pad<1
    continuation = ""   # base text continuing from previous page's last entry
    mode = "startup"    # startup, header, body
    entries = []        # list of (header, text) tuples
    current_entry = ["", ""]  # current entry (header, text)
    done = False        # whether we've reached the end of the chapter (e.x. sugguested readings section)
    
    SKIP_BADPUNC = True
    
    pg_num = pg.page_number
    im = pg.to_image(resolution=resolution).annotated
    labels = get_labels(im)
    
    w_im,h_im = im.size
    w_pg,h_pg = pg.width,pg.height
    w_ratio,h_ratio = w_pg/w_im,h_pg/h_im
    
    for j,label in enumerate(labels):
        label: TextBlock
        pad_x, pad_y = pad*w_im, pad*h_im
        label = label.pad(left=pad_x, right=pad_x, top=pad_y, bottom=pad_y)
        # print(label)
        
        kind = label.type
        # assert kind in ("Text", "Title")
                
        x0,y0,x1,y1 = label.coordinates
        x0,x1 = x0*w_ratio, x1*w_ratio
        y0,y1 = y0*h_ratio, y1*h_ratio

        area = pg.within_bbox((x0,y0,x1,y1))

        if kind in ("Text", "Title"):
            fonts = extract_fonts(pg)   # TODO continue iff font matches previous
            txt = area.crop()
            # print(txt)
            txt = process_text(txt, pg_num=pg_num)
            # print(txt)
            
            if txt == 'SUGGESTED READING':
                print(f'### PG {pg_num} :: Found end of chapter, stopping early ###')
                done = True
                if mode == "body":
                    entries.append(current_entry)
                    # entries.append([ent.rstrip() for ent in current_entry])
                return entries, continuation.rstrip(), done

            if kind == "Title":
                match mode:
                    case "header":
                        current_entry[0] += txt
                    case "startup":
                        if continuation!="" and not continuation.rstrip().endswith(TOK_SENTENCE_TERMS):
                            print(f'### PG {pg_num}, Box {j} :: Continuation does not end with punctuation: {continuation.rstrip()[-1]}')
                            if SKIP_BADPUNC: 
                                print(f'### > skipping `{txt}`')
                                continue
                        mode = "header"
                        current_entry = [txt, ""]
                    case "body":
                        if current_entry[1]!="" and not current_entry[1].rstrip().endswith(TOK_SENTENCE_TERMS):
                            print(f'### PG {pg_num}, Box {j} :: Body does not end with punctuation: {current_entry[1].rstrip()[-1]}')
                            if SKIP_BADPUNC: 
                                print(f'### > skipping `{txt}`')
                                continue
                        mode = "header"
                        entries.append(current_entry)
                        # entries.append([ent.rstrip() for ent in current_entry])
                        current_entry = [txt, ""]
            elif kind == "Text":
                match mode:
                    case "header":
                        mode = "body"
                        current_entry[1] += txt
                    case "startup":
                        if txt.endswith(TOK_SENTENCE_TERMS):
                            txt += "\n"
                        continuation += txt
                    case "body":
                        # if re.match(r'[.?!]', txt[-1]):
                        if txt.endswith(TOK_SENTENCE_TERMS):
                            txt += "\n"
                        current_entry[1] += txt

    match mode:
        case "body":
            # entries.append([ent.rstrip() for ent in current_entry])
            entries.append(current_entry)
        case "header", "startup":
            print("### Ended on", mode, "-- this should not happen")
    
            
    continuation = process_text(continuation)
    for i, (_h, b) in enumerate(entries):
        entries[i][1] = process_text(b)

    return entries, continuation, done

# %%
ent, cont, done = process_page_DNN(pg)

print('\n' + '='*60)
print("cont:", cont, "\n")
for h, b in ent:
    print("**", h, "**")
    print(b)
    print()
# Out:
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=246.48963928222656, y_1=78.03372192382812, x_2=978.2208862304688, y_2=443.8672180175781), text=None, id=None, type=Figure, parent=None, next=None, score=0.9958802461624146), TextBlock(block=Rectangle(x_1=241.49267578125, y_1=715.4127807617188, x_2=977.7689819335938, y_2=1020.5606079101562), text=None, id=None, type=Figure, parent=None, next=None, score=0.9919597506523132), TextBlock(block=Rectangle(x_1=229.37704467773438, y_1=1041.241943359375, x_2=967.0467529296875, y_2=1274.6651611328125), text=None, id=None, type=List, parent=None, next=None, score=0.9890110492706299), TextBlock(block=Rectangle(x_1=129.15890502929688, y_1=690.24072265625, x_2=325.67657470703125, y_2=710.0797119140625), text=None, id=None, type=Title, parent=None, next=None, score=0.9823071956634521), TextBlock(block=Rectangle(x_1=228.14312744140625, y_1=463.4031677246094, x_2=982.053955078125, y_2=681.5524291992188), text=None, id=None, type=List, parent=None, next=None, score=0.9819470643997192)], page_data={})
#
# ============================================================
# cont:

# %%
im = pg.to_image(resolution=123).annotated
plt.figure(figsize=(10,10), dpi=123)
plt.axis("off")
plt.imshow(im);

# %%
from tqdm.notebook import tqdm
import json

def process_file(fname: Path):
    config = Config(fname)
    chapters = config.chapter_range()
    # chapters = [config.chapter_range()[0]]
    pdf = pdfplumber.open(fname, laparams=dict(detect_vertical=False)).pages
    # word_margin=0.08  -- this doesn't cause any difference?
    
    for i, ch in enumerate(chapters,1):
        # pdf: fitz.Document = fitz.open(fname)
        # pdf.select(range(*ch))
        
        start, end = ch
        pages = pdf[start:end]
        
        print(f"Processing ch{i}")

        ch_entries = []
        
        progress = tqdm(pages)
        for pg in progress:
        # for pg in pdf:
            entries, cont, done = process_page_DNN(pg)
            # entries, cont, done = process_page(pg)

            if cont:
                if len(ch_entries):
                    ch_entries[-1][1] = ch_entries[-1][1] + cont
                else:
                    ch_entries.append(["[Chapter Introduction]", cont])

            ch_entries += entries

            if done:
                progress.close()
                break

        outdir = Path("scrape_out_old")
        outdir /= fname.stem
        outdir.mkdir(parents=True, exist_ok=True)
        with open(outdir / f"ch{i}.json", "w", encoding="utf8") as f:
            json.dump(ch_entries, f, indent=False, ensure_ascii=False)
            print(f"Saved to {f.name}")
            
process_file(fname)
# Out:
# Processing ch1
#   0%|          | 0/86 [00:00<?, ?it/s]
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=104.80734252929688, y_1=193.57278442382812, x_2=973.8204956054688, y_2=1330.8260498046875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9799686670303345)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=202.29281616210938, y_1=1014.3544311523438, x_2=939.4034423828125, y_2=1252.98583984375), text=None, id=None, type=List, parent=None, next=None, score=0.9926942586898804), TextBlock(block=Rectangle(x_1=199.04989624023438, y_1=175.96133422851562, x_2=951.5613403320312, y_2=973.5158081054688), text=None, id=None, type=Figure, parent=None, next=None, score=0.9745982885360718), TextBlock(block=Rectangle(x_1=85.97779846191406, y_1=127.90338134765625, x_2=177.96737670898438, y_2=157.1876983642578), text=None, id=None, type=Title, parent=None, next=None, score=0.793149471282959), TextBlock(block=Rectangle(x_1=107.79412078857422, y_1=990.101806640625, x_2=240.0605926513672, y_2=1010.4228515625), text=None, id=None, type=Text, parent=None, next=None, score=0.7693758606910706)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=201.5869598388672, y_1=550.5076904296875, x_2=973.0538330078125, y_2=1081.2288818359375), text=None, id=None, type=List, parent=None, next=None, score=0.986024796962738), TextBlock(block=Rectangle(x_1=225.34005737304688, y_1=84.38816833496094, x_2=944.965087890625, y_2=550.1522827148438), text=None, id=None, type=List, parent=None, next=None, score=0.9637901782989502), TextBlock(block=Rectangle(x_1=213.11968994140625, y_1=1117.55517578125, x_2=959.9511108398438, y_2=1283.0234375), text=None, id=None, type=List, parent=None, next=None, score=0.954086184501648), TextBlock(block=Rectangle(x_1=104.63304901123047, y_1=1088.0205078125, x_2=280.277099609375, y_2=1112.594482421875), text=None, id=None, type=Title, parent=None, next=None, score=0.9486364126205444), TextBlock(block=Rectangle(x_1=127.71174621582031, y_1=533.4674682617188, x_2=313.7223205566406, y_2=554.418701171875), text=None, id=None, type=Text, parent=None, next=None, score=0.9334232211112976)], page_data={})
# ### PG 15, Box 1 :: Continuation does not end with punctuation: s
# ### > skipping `Lobar atelectasis`
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=200.99159240722656, y_1=49.87550735473633, x_2=917.6773681640625, y_2=1242.4237060546875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9965941309928894), TextBlock(block=Rectangle(x_1=221.2226104736328, y_1=1236.3548583984375, x_2=918.104736328125, y_2=1257.244384765625), text=None, id=None, type=Text, parent=None, next=None, score=0.8841797113418579)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=246.48963928222656, y_1=78.03372192382812, x_2=978.2208862304688, y_2=443.8672180175781), text=None, id=None, type=Figure, parent=None, next=None, score=0.9958802461624146), TextBlock(block=Rectangle(x_1=241.49267578125, y_1=715.4127807617188, x_2=977.7689819335938, y_2=1020.5606079101562), text=None, id=None, type=Figure, parent=None, next=None, score=0.9919597506523132), TextBlock(block=Rectangle(x_1=229.37704467773438, y_1=1041.241943359375, x_2=967.0467529296875, y_2=1274.6651611328125), text=None, id=None, type=List, parent=None, next=None, score=0.9890110492706299), TextBlock(block=Rectangle(x_1=129.15890502929688, y_1=690.24072265625, x_2=325.67657470703125, y_2=710.0797119140625), text=None, id=None, type=Title, parent=None, next=None, score=0.9823071956634521), TextBlock(block=Rectangle(x_1=228.14312744140625, y_1=463.4031677246094, x_2=982.053955078125, y_2=681.5524291992188), text=None, id=None, type=List, parent=None, next=None, score=0.9819470643997192)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=226.09521484375, y_1=710.1721801757812, x_2=964.181640625, y_2=1105.1702880859375), text=None, id=None, type=Figure, parent=None, next=None, score=0.9972877502441406), TextBlock(block=Rectangle(x_1=234.1103973388672, y_1=77.97721862792969, x_2=944.48583984375, y_2=472.69781494140625), text=None, id=None, type=Figure, parent=None, next=None, score=0.9972214698791504), TextBlock(block=Rectangle(x_1=109.15101623535156, y_1=681.1122436523438, x_2=303.9041442871094, y_2=701.61474609375), text=None, id=None, type=
], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=517.38818359375, y_1=1034.1929931640625, x_2=943.9483642578125, y_2=1092.211669921875), text=None, id=None, type=Text, parent=None, next=None, score=0.9898998141288757), TextBlock(block=Rectangle(x_1=499.8200988769531, y_1=76.4464111328125, x_2=951.6734008789062, y_2=371.10107421875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9881954193115234), TextBlock(block=Rectangle(x_1=472.4653625488281, y_1=717.8057250976562, x_2=952.6416625976562, y_2=1022.291748046875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9522615075111389), TextBlock(block=Rectangle(x_1=510.2873840332031, y_1=383.97747802734375, x_2=952.9623413085938, y_2=442.61309814453125), text=None, id=None, type=Text, parent=None, next=None, score=0.9218414425849915), TextBlock(block=Rectangle(x_1=239.9862060546875, y_1=90.44248962402344, x_2=514.7008666992188, y_2=378.802734375), text=None, id=None, type=Figure, parent=None, next=None, score=0.9208951592445374), TextBlock(block=Rectangle(x_1=237.4945068359375, y_1=383.39483642578125, x_2=466.99468994140625, y_2=419.5510559082031), text=None, id=None, type=Text, parent=None, next=None, score=0.9184369444847107), TextBlock(block=Rectangle(x_1=205.2300567626953, y_1=472.633056640625, x_2=963.73681640625, y_2=666.0877075195312), text=None, id=None, type=List, parent=None, next=None, score=0.8265331387519836), TextBlock(block=Rectangle(x_1=208.27957153320312, y_1=1032.1629638671875, x_2=961.6854858398438, y_2=1241.5426025390625), text=None, id=None, type=List, parent=None, next=None, score=0.7686097025871277), TextBlock(block=Rectangle(x_1=239.5734100341797, y_1=385.87237548828125, x_2=468.484130859375, y_2=402.1139221191406), text=None, id=None, type=Text, parent=None, next=None, score=0.7002705931663513)], page_data={})
# %%% Text block 0 is inside 1 -- skipping
# %%% Text block 1 is inside 0 -- skipping
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=551.8825073242188, y_1=72.69881439208984, x_2=978.267822265625, y_2=383.0455627441406), text=None, id=None, type=Figure, parent=None, next=None, score=0.9944268465042114), TextBlock(block=Rectangle(x_1=561.7964477539062, y_1=396.31488037109375, x_2=966.459228515625, y_2=473.99639892578125), text=None, id=None, type=Text, parent=None, next=None, score=0.9734041094779968), TextBlock(block=Rectangle(x_1=251.59060668945312, y_1=86.78125, x_2=526.6349487304688, y_2=387.4625244140625), text=None, id=None, type=Figure, parent=None, next=None, score=0.9323012232780457), TextBlock(block=Rectangle(x_1=255.89468383789062, y_1=394.35211181640625, x_2=507.8551330566406, y_2=456.09136962890625), text=None, id=None, type=Text, parent=None, next=None, score=0.8892135620117188), TextBlock(block=Rectangle(x_1=223.57701110839844, y_1=458.3391418457031, x_2=926.7777099609375, y_2=849.0538330078125), text=None, id=None, type=List, parent=None, next=None, score=0.8498572707176208)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1
], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=540.1525268554688, y_1=76.87049102783203, x_2=971.724365234375, y_2=375.7176818847656), text=None, id=None, type=Figure, parent=None, next=None, score=0.9941456317901611), TextBlock(block=Rectangle(x_1=259.1972351074219, y_1=395.1073303222656, x_2=514.1015014648438, y_2=435.5762939453125), text=None, id=None, type=Text, parent=None, next=None, score=0.9230489730834961), TextBlock(block=Rectangle(x_1=277.1758728027344, y_1=90.86943817138672, x_2=641.1322631835938, y_2=379.49810791015625), text=None, id=None, type=Figure, parent=None, next=None, score=0.904622495174408), TextBlock(block=Rectangle(x_1=219.32012939453125, y_1=441.3363037109375, x_2=963.5045776367188, y_2=763.392822265625), text=None, id=None, type=List, parent=None, next=None, score=0.8862579464912415), TextBlock(block=Rectangle(x_1=543.1879272460938, y_1=397.172607421875, x_2=970.8215942382812, y_2=481.64410400390625), text=None, id=None, type=Text, parent=None, next=None, score=0.7642273306846619)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=588.9683837890625, y_1=108.82025146484375, x_2=956.7953491210938, y_2=407.8096008300781), text=None, id=None, type=Figure, parent=None, next=None, score=0.994594156742096), TextBlock(block=Rectangle(x_1=586.3310546875, y_1=705.1834716796875, x_2=958.3174438476562, y_2=1007.4448852539062), text=None, id=None, type=Figure, parent=None, next=None, score=0.9898678064346313), TextBlock(block=Rectangle(x_1=591.5438842773438, y_1=417.31658935546875, x_2=931.7637939453125, y_2=474.9990234375), text=None, id=None, type=Text, parent=None, next=None, score=0.985186755657196), TextBlock(block=Rectangle(x_1=591.6893920898438, y_1=1020.3041381835938, x_2=954.941162109375, y_2=1078.3082275390625), text=None, id=None, type=Text, parent=None, next=None, score=0.9831310510635376), TextBlock(block=Rectangle(x_1=236.86546325683594, y_1=1020.8836669921875, x_2=548.03173828125, y_2=1058.9825439453125), text=None, id=None, type=Text, parent=None, next=None, score=0.9725534319877625), TextBlock(block=Rectangle(x_1=108.3520278930664, y_1=700.217529296875, x_2=291.93438720703125, y_2=721.5519409179688), text=None, id=None, type=Text, parent=None, next=None, score=0.8907723426818848), TextBlock(block=Rectangle(x_1=250.3580780029297, y_1=119.09686279296875, x_2=542.7763671875, y_2=394.19390869140625), text=None, id=None, type=Figure, parent=None, next=None, score=0.8773833513259888), TextBlock(block=Rectangle(x_1=249.26242065429688, y_1=748.3938598632812, x_2=541.2599487304688, y_2=1005.7670288085938), text=None, id=None, type=Figure, parent=None, next=None, score=0.8601362109184265), TextBlock(block=Rectangle(x_1=590.9664916992188, y_1=1089.5057373046875, x_2=931.3760986328125, y_2=1128.0726318359375), text=None, id=None, type=Text, parent=None, next=None, score=0.7863373756408691), TextBlock(block=Rectangle(x_1=209.90313720703125, y_1=1132.9180908203125, x_2=940.9741821289062, y_2=1243.2578125), text=None, id=None, type=List, parent=None, next=None, score=0.7229428291320801), TextBlock(block=Rectangle(x_1=208.7393035888672, y_1=1137.234130859375, x_2=958.9105224609375, y_2=1158.6934814453125), text=None, id=None, type=Text, parent=None, next=None, score=0.7095056772232056)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1
], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=212.9467315673828, y_1=185.2944793701172, x_2=962.8521118164062, y_2=435.3069763183594), text=None, id=None, type=List, parent=None, next=None, score=0.9911713004112244), TextBlock(block=Rectangle(x_1=216.28550720214844, y_1=460.38946533203125, x_2=972.3732299804688, y_2=535.3551025390625), text=None, id=None, type=List, parent=None, next=None, score=0.9542833566665649), TextBlock(block=Rectangle(x_1=215.69564819335938, y_1=674.219482421875, x_2=925.666748046875, y_2=748.5467529296875), text=None, id=None, type=List, parent=None, next=None, score=0.9278564453125), TextBlock(block=Rectangle(x_1=128.9066925048828, y_1=1183.722412109375, x_2=254.40438842773438, y_2=1202.4300537109375), text=None, id=None, type=Title, parent=None, next=None, score=0.9259249567985535), TextBlock(block=Rectangle(x_1=129.46116638183594, y_1=647.7658081054688, x_2=409.1830749511719, y_2=668.6683349609375), text=None, id=None, type=Title, parent=None, next=None, score=0.9074150919914246), TextBlock(block=Rectangle(x_1=187.67922973632812, y_1=981.7028198242188, x_2=972.50048828125, y_2=1287.3294677734375), text=None, id=None, type=List, parent=None, next=None, score=0.9045814275741577), TextBlock(block=Rectangle(x_1=129.2914581298828, y_1=542.460693359375, x_2=433.2572937011719, y_2=562.916259765625), text=None, id=None, type=Title, parent=None, next=None, score=0.8715234994888306), TextBlock(block=Rectangle(x_1=123.56353759765625, y_1=995.738037109375, x_2=423.50604248046875, y_2=1017.2188110351562), text=None, id=None, type=Title, parent=None, next=None, score=0.8649993538856506), TextBlock(block=Rectangle(x_1=127.72074890136719, y_1=756.8538818359375, x_2=469.5603942871094, y_2=776.0281982421875), text=None, id=None, type=Title, parent=None, next=None, score=0.8592843413352966), TextBlock(block=Rectangle(x_1=104.62832641601562, y_1=131.07798767089844, x_2=489.8261413574219, y_2=156.83670043945312), text=None, id=None, type=Title, parent=None, next=None, score=0.8589740991592407), TextBlock(block=Rectangle(x_1=167.51417541503906, y_1=154.52755737304688, x_2=971.0828857421875, y_2=747.47705078125), text=None, id=None, type=List, parent=None, next=None, score=0.8466350436210632), TextBlock(block=Rectangle(x_1=129.4608612060547, y_1=435.27508544921875, x_2=386.8324279785156, y_2=455.9803161621094), text=None, id=None, type=Title, parent=None, next=None, score=0.817138135433197), TextBlock(block=Rectangle(x_1=106.75899505615234, y_1=849.41943359375, x_2=476.10455322265625, y_2=874.4176025390625), text=None, id=None, type=Title, parent=None, next=None, score=0.7817068696022034), TextBlock(block=Rectangle(x_1=216.51742553710938, y_1=781.2930297851562, x_2=967.0087890625, y_2=832.8612670898438), text=None, id=None, type=List, parent=None, next=None, score=0.752609372138977), TextBlock(block=Rectangle(x_1=204.1857147216797, y_1=563.0778198242188, x_2=958.8286743164062, y_2=646.56103515625), text=None, id=None, type=List, parent=None, next=None, score=0.7304717302322388)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1
, id=None, type=Text, parent=None, next=None, score=0.9674814343452454), TextBlock(block=Rectangle(x_1=618.59033203125, y_1=303.1846008300781, x_2=940.693603515625, y_2=341.5638732910156), text=None, id=None, type=Text, parent=None, next=None, score=0.9547935724258423), TextBlock(block=Rectangle(x_1=110.80500793457031, y_1=417.84130859375, x_2=392.9560241699219, y_2=438.35272216796875), text=None, id=None, type=Text, parent=None, next=None, score=0.9339073300361633), TextBlock(block=Rectangle(x_1=264.81689453125, y_1=122.45599365234375, x_2=577.76953125, y_2=402.69573974609375), text=None, id=None, type=Figure, parent=None, next=None, score=0.899626612663269), TextBlock(block=Rectangle(x_1=244.05686950683594, y_1=937.9258422851562, x_2=735.8094482421875, y_2=957.9041137695312), text=None, id=None, type=Text, parent=None, next=None, score=0.8767793774604797), TextBlock(block=Rectangle(x_1=621.2899780273438, y_1=211.03237915039062, x_2=948.616943359375, y_2=292.4112243652344), text=None, id=None, type=Title, parent=None, next=None, score=0.8710641264915466)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=128.3221893310547, y_1=643.828369140625, x_2=271.1337890625, y_2=663.7772216796875), text=None, id=None, type=Title, parent=None, next=None, score=0.9982520937919617), TextBlock(block=Rectangle(x_1=252.5928955078125, y_1=74.96408081054688, x_2=963.6994018554688, y_2=437.6522521972656), text=None, id=None, type=Figure, parent=None, next=None, score=0.9964776635169983), TextBlock(block=Rectangle(x_1=250.92095947265625, y_1=669.3451538085938, x_2=977.6134643554688, y_2=1034.1588134765625), text=None, id=None, type=Figure, parent=None, next=None, score=0.9945110082626343), TextBlock(block=Rectangle(x_1=225.6782989501953, y_1=530.42236328125, x_2=978.143798828125, y_2=634.57861328125), text=None, id=None, type=List, parent=None, next=None, score=0.9873979091644287), TextBlock(block=Rectangle(x_1=255.74346923828125, y_1=450.53778076171875, x_2=968.0453491210938, y_2=490.74566650390625), text=None, id=None, type=Text, parent=None, next=None, score=0.9832652807235718), TextBlock(block=Rectangle(x_1=256.3075256347656, y_1=1045.47119140625, x_2=969.84521484375, y_2=1084.8865966796875), text=None, id=None, type=Text, parent=None, next=None, score=0.9821049571037292), TextBlock(block=Rectangle(x_1=229.75405883789062, y_1=1126.4027099609375, x_2=879.33251953125, y_2=1205.15869140625), text=None, id=None, type=List, parent=None, next=None, score=0.949152946472168), TextBlock(block=Rectangle(x_1=261.72418212890625, y_1=1093.017333984375, x_2=741.28369140625, y_2=1112.5225830078125), text=None, id=None, type=Text, parent=None, next=None, score=0.9389122128486633), TextBlock(block=Rectangle(x_1=258.1775817871094, y_1=497.961669921875, x_2=738.4298706054688, y_2=517.546875), text=None, id=None, type=Text, parent=None, next=None, score=0.9173821210861206)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=227.60862731933594, y_1=110.16051483154297, x_2=960.2225952148438, y_2=408.7921142578125), text=None, id=None, type=Figure, parent=None, next=None, score=0.9948261380195618), TextBlock(block=Rectangle(x_1=189.8546905517578, y_1=1133.7109375, x_2=944.4790649414062, y_2=1282.2569580078125), text=None, id=None, type=List, parent=None, next=None, score=0.9892701506614685), TextBlock(block=Rectangle(x_1=204.28555297
Block(block=Rectangle(x_1=732.4634399414062, y_1=831.2449951171875, x_2=963.9920043945312, y_2=871.711181640625), text=None, id=None, type=Text, parent=None, next=None, score=0.8519508838653564), TextBlock(block=Rectangle(x_1=128.09266662597656, y_1=691.2368774414062, x_2=315.7127380371094, y_2=710.3245849609375), text=None, id=None, type=Title, parent=None, next=None, score=0.7284415364265442)], page_data={})
# ...
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=211.6825408935547, y_1=78.17195892333984, x_2=967.9346923828125, y_2=545.1904907226562), text=None, id=None, type=List, parent=None, next=None, score=0.9975899457931519), TextBlock(block=Rectangle(x_1=216.55490112304688, y_1=754.9260864257812, x_2=964.3236083984375, y_2=969.8076782226562), text=None, id=None, type=List, parent=None, next=None, score=0.989314079284668), TextBlock(block=Rectangle(x_1=220.192626953125, y_1=625.4281005859375, x_2=935.694091796875, y_2=729.3707275390625), text=None, id=None, type=List, parent=None, next=None, score=0.9528002738952637), TextBlock(block=Rectangle(x_1=128.02685546875, y_1=735.1578369140625, x_2=465.5257263183594, y_2=755.3734130859375), text=None, id=None, type=Title, parent=None, next=None, score=0.9407499432563782), TextBlock(block=Rectangle(x_1=107.31939697265625, y_1=1068.1842041015625, x_2=959.5232543945312, y_2=1109.630859375), text=None, id=None, type=Text, parent=None, next=None, score=0.8925075531005859), TextBlock(block=Rectangle(x_1=128.60130310058594, y_1=567.844970703125, x_2=743.8081665039062, y_2=593.3794555664062), text=None, id=None, type=Title, parent=None, next=None, score=0.8676230907440186)], page_data={})
# ### PG 855 :: Failed to dehyphenate word: org/Quality-Safety/Resources/Contrast-manual,
# ### Failed to dehyphenate word: org/Quality-Safety/Resources/Contrast-manual,
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=151.97113037109375, y_1=174.19635009765625, x_2=950.5855102539062, y_2=673.2127685546875), text=None, id=None, type=List, parent=None, next=None, score=0.9893481731414795), TextBlock(block=Rectangle(x_1=202.80960083007812, y_1=835.2578125, x_2=641.0410766601562, y_2=1194.7783203125), text=None, id=None, type=List, parent=None, next=None, score=0.9645130038261414), TextBlock(block=Rectangle(x_1=212.30262756347656, y_1=693.7127075195312, x_2=935.68212890625, y_2=762.8673706054688), text=None, id=None, type=List, parent=None, next=None, score=0.8719448447227478), TextBlock(block=Rectangle(x_1=208.54916381835938, y_1=791.2508544921875, x_2=434.2777404785156, y_2=814.7684936523438), text=None, id=None, type=Title, parent=None, next=None, score=0.8608442544937134), TextBlock(block=Rectangle(x_1=556.6323852539062, y_1=792.2295532226562, x_2=645.640380859375, y_2=814.8198852539062), text=None, id=None, type=Title, parent=None, next=None, score=0.83259516954422), TextBlock(block=Rectangle(x_1=568.8013916015625, y_1=1097.404296875, x_2=860.8087768554688, y_2=1146.5859375), text=None, id=None, type=List, parent=None, next=None, score=0.7796176671981812)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=111.59494018554688, y_1=100.95579528808594, x_2=225.9801483154297, y_2=119.65513610839844), text=None, id=None, type=Title, parent=None, next=None, score=0.9600913524627686), TextBlock(block=Rectangle(x_1=255.7101593017578, y_1=101.08647155761719, x_2=958.7396240234375, y_2=383.8337707519531), text=None, id=None, type=List, parent=None, next=None, score=0.9132413864135742), TextBlock(block=Rectangle(x_1=271.1333923339844, y_1=195.39590454101562, x_2=963.3607788085938, y_2=871.6449584960938), text=None, id=None, type=Figure, parent=None, next=None, score=0.8795616626739502), TextBlock(block=Rectangle(x_1=738.7518920898438, y_1=1182.5155029296875, x_2=949.1600341796875, y_2=1202.9591064453125), text=None, id=None, type=Text, parent=None, next=None, score=0.8662307262420654), TextBlock(block=Rectangle(x_1=700.6967163085938, y_1=1080.2220458984375, x_2=949.7597045898438, y_2=1179.4658203125), text=None, id=None, type=List, parent=None, next=None, score=0.8552188873291016)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=365.7441711425781, y_1=1184.478759765625, x_2=940.3414306640625, y_2=1244.075927734375), text=None, id=None, type=Text, parent=None, next=None, score=0.9695338010787964), TextBlock(block=Rectangle(x_1=365.4193420410156, y_1=820.4454345703125, x_2=939.4793090820312, y_2=1172.6676025390625), text=None, id=None, type=Figure, parent=None, next=None, score=0.9430108666419983), TextBlock(block=Rectangle(x_1=168.12229919433594, y_1=42.248085021972656, x_2=919.7319946289062, y_2=873.9242553710938), text=None, id=None, type=Figure, parent=None, next=None, score=0.9234731197357178), TextBlock(block=Rectangle(x_1=331.77081298828125, y_1=401.7783203125, x_2=926.3224487304688, y_2=1167.2396240234375), text=None, id=None, type=Figure, parent=None, next=None, score=0.8524682521820068)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=330.56036376953125, y_1=919.6779174804688, x_2=928.5478515625, y_2=1197.542236328125), text=None, id=None, type=List, parent=None, next=None, score=0.9642150402069092), TextBlock(block=Rectangle(x_1=645.6807861328125, y_1=67.40460205078125, x_2=928.0577392578125, y_2=133.85069274902344), text=None, id=None, type=List, parent=None, next=None, score=0.8654676079750061), TextBlock(block=Rectangle(x_1=645.475830078125, y_1=169.2808837890625, x_2=915.5896606445312, y_2=208.32969665527344), text=None, id=None, type=Text, parent=None, next=None, score=0.8018703460693359)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=208.12852478027344, y_1=52.651458740234375, x_2=955.9788208007812, y_2=787.2036743164062), text=None, id=None, type=List, parent=None, next=None, score=0.9028666615486145), TextBlock(block=Rectangle(x_1=214.4786376953125, y_1=467.9601135253906, x_2=963.2102661132812, y_2=800.1170043945312), text=None, id=None, type=Figure, parent=None, next=None, score=0.8741979598999023), TextBlock(block=Rectangle(x_1=151.94918823242188, y_1=790.8092041015625, x_2=954.5037841796875, y_2=1281.0067138671875), text=None, id=None, type=List, parent=None, next=None, score=0.8662945032119751)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=281.0669250488281, y_1=808.46923828125, x_2=951.1417236328125, y_2=1123.121826171875), text=None, id=None, type=List, parent=None, next=None, score=0.8692939281463623), TextBlock(block=Rectangle(x_1=610.1088256835938, y_1=102.14776611328125, x_2=958.4281616210938, y_2=593.0122680664062), text=None, id=None, type=List, parent=None, next=None, score=0.8569482564926147), TextBlock(block=Rectangle(x_1=284.3539123535156, y_1=99.31267547607422, x_2=555.6205444335938, y_2=156.6613006591797), text=None, id=None, type=List, parent=None, next=None, score=0.7021604180335999)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=267.728271484375, y_1=664.353515625, x_2=918.5526123046875, y_2=878.8596801757812), text=None, id=None, type=List, parent=None, next=None, score=0.8281959295272827), TextBlock(block=Rectangle(x_1=249.2322235107422, y_1=1114.336181640625, x_2=913.6295166015625, y_2=1242.3958740234375), text=None, id=None, type=List, parent=None, next=None, score=0.7361322045326233)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=286.0170593261719, y_1=468.3920593261719, x_2=972.3594360351562, y_2=737.8931884765625), text=None, id=None, type=List, parent=None, next=None, score=0.951259195804596), TextBlock(block=Rectangle(x_1=294.88653564453125, y_1=1010.5548095703125, x_2=873.0560913085938, y_2=1155.044921875), text=None, id=None, type=List, parent=None, next=None, score=0.8214484453201294), TextBlock(block=Rectangle(x_1=137.24505615234375, y_1=84.8242416381836, x_2=962.6928100585938, y_2=827.5944213867188), text=None, id=None, type=List, parent=None, next=None, score=0.7288259267807007)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=221.22337341308594, y_1=97.00447082519531, x_2=934.6851806640625, y_2=469.2494812011719), text=None, id=None, type=List, parent=None, next=None, score=0.9760596752166748), TextBlock(block=Rectangle(x_1=93.20633697509766, y_1=101.39594268798828, x_2=184.92921447753906, y_2=121.32758331298828), text=None, id=None, type=Title, parent=None, next=None, score=0.9330491423606873), TextBlock(block=Rectangle(x_1=643.2637939453125, y_1=881.8059692382812, x_2=942.7965087890625, y_2=1169.06201171875), text=None, id=None, type=List, parent=None, next=None, score=0.8199528455734253), TextBlock(block=Rectangle(x_1=81.40340423583984, y_1=537.297607421875, x_2=947.7244262695312, y_2=1220.10986328125), text=None, id=None, type=Table, parent=None, next=None, score=0.7459464073181152)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=263.335693359375, y_1=1045.1441650390625, x_2=932.8259887695312, y_2=1287.268310546875), text=None, id=None, type=List, parent=None, next=None, score=0.9772591590881348), TextBlock(block=Rectangle(x_1=105.067626953125, y_1=72.12097930908203, x_2=942.5811767578125, y_2=1179.7818603515625), text=None, id=None, type=Figure, parent=None, next=None, score=0.8018158674240112), TextBlock(block=Rectangle(x_1=99.75101470947266, y_1=113.82337188720703, x_2=967.1159057617188, y_2=451.1078796386719), text=None, id=None, type=List, parent=None, next=None, score=0.7312313318252563), TextBlock(block=Rectangle(x_1=265.3550109863281, y_1=735.150390625, x_2=966.6303100585938, y_2=1046.467041015625), text=None, id=None, type=Figure, parent=None, next=None, score=0.7284504175186157)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=251.67620849609375, y_1=860.880615234375, x_2=960.1486206054688, y_2=1016.439208984375), text=None, id=None, type=List, parent=None, next=None, score=0.9818783402442932), TextBlock(block=Rectangle(x_1=272.8418273925781, y_1=1062.20703125, x_2=904.5968017578125, y_2=1205.128662109375), text=None, id=None, type=List, parent=None, next=None, score=0.9697073101997375), TextBlock(block=Rectangle(x_1=166.37835693359375, y_1=143.79434204101562, x_2=954.293212890625, y_2=834.0505981445312), text=None, id=None, type=List, parent=None, next=None, score=0.9161832928657532), TextBlock(block=Rectangle(x_1=330.0872802734375, y_1=813.9351196289062, x_2=783.641357421875, y_2=833.4805908203125), text=None, id=None, type=Text, parent=None, next=None, score=0.7433893084526062)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=273.2640075683594, y_1=58.012996673583984, x_2=965.0638427734375, y_2=459.6842041015625), text=None, id=None, type=List, parent=None, next=None, score=0.9935382008552551), TextBlock(block=Rectangle(x_1=293.5291748046875, y_1=1186.9920654296875, x_2=955.2049560546875, y_2=1265.665283203125), text=None, id=None, type=List, parent=None, next=None, score=0.8691030740737915), TextBlock(block=Rectangle(x_1=147.56497192382812, y_1=11.51195240020752, x_2=955.1824951171875, y_2=1251.1943359375), text=None, id=None, type=List, parent=None, next=None, score=0.857134222984314), TextBlock(block=Rectangle(x_1=237.2473907470703, y_1=914.8316650390625, x_2=882.2868041992188, y_2=1158.283447265625), text=None, id=None, type=List, parent=None, next=None, score=0.7600243091583252)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=273.2139892578125, y_1=269.2620849609375, x_2=933.5098266601562, y_2=542.113525390625), text=None, id=None, type=List, parent=None, next=None, score=0.8592813611030579), TextBlock(block=Rectangle(x_1=104.53268432617188, y_1=619.5349731445312, x_2=881.8411865234375, y_2=1235.7247314453125), text=None, id=None, type=Table, parent=None, next=None, score=0.801460325717926), TextBlock(block=Rectangle(x_1=237.56063842773438, y_1=1044.9366455078125, x_2=940.5843505859375, y_2=1153.9305419921875), text=None, id=None, type=List, parent=None, next=None, score=0.7719192504882812), TextBlock(block=Rectangle(x_1=85.45213317871094, y_1=97.59781646728516, x_2=945.440185546875, y_2=576.7628784179688), text=None, id=None, type=Table, parent=None, next=None, score=0.7462155818939209)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=229.78182983398438, y_1=526.08447265625, x_2=966.3905029296875, y_2=1080.286865234375), text=None, id=None, type=List, parent=None, next=None, score=0.9880820512771606), TextBlock(block=Rectangle(x_1=206.80943298339844, y_1=67.20364379882812, x_2=944.5361328125, y_2=221.7392578125), text=None, id=None, type=List, parent=None, next=None, score=0.9820576906204224), TextBlock(block=Rectangle(x_1=305.36602783203125, y_1=1065.5711669921875, x_2=935.0716552734375, y_2=1083.837890625), text=None, id=None, type=Text, parent=None, next=None, score=0.9203317165374756), TextBlock(block=Rectangle(x_1=111.2993392944336, y_1=527.9627685546875, x_2=182.6322479248047, y_2=547.9979858398438), text=None, id=None, type=Title, parent=None, next=None, score=0.9106351733207703), TextBlock(block=Rectangle(x_1=307.1534729003906, y_1=405.2267150878906, x_2=782.2116088867188, y_2=423.364990234375), text=None, id=None, type=Text, parent=None, next=None, score=0.8613764047622681), TextBlock(block=Rectangle(x_1=308.7593994140625, y_1=327.64111328125, x_2=925.9388427734375, y_2=346.769287109375), text=None, id=None, type=Text, parent=None, next=None, score=0.8513774871826172), TextBlock(block=Rectangle(x_1=320.4610900878906, y_1=381.6817321777344, x_2=790.7115478515625, y_2=397.7547302246094), text=None, id=None, type=Text, parent=None, next=None, score=0.8393853306770325)], page_data={})
# ### PG 869, Box 2 :: Continuation does not end with punctuation: n
# ### > skipping `T 1 and T 2`
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=96.4669189453125, y_1=72.49151611328125, x_2=954.2345581054688, y_2=1193.8377685546875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9932489395141602)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=91.62776947021484, y_1=69.23589324951172, x_2=952.5882568359375, y_2=1281.6153564453125), text=None, id=None, type=Table, parent=None, next=None, score=0.7489868402481079)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=298.40191650390625, y_1=988.446044921875, x_2=913.1170043945312, y_2=1178.185546875), text=None, id=None, type=List, parent=None, next=None, score=0.9890598058700562), TextBlock(block=Rectangle(x_1=145.0880889892578, y_1=44.43119430541992, x_2=904.3114624023438, y_2=1159.4383544921875), text=None, id=None, type=List, parent=None, next=None, score=0.737580418586731)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=287.5642395019531, y_1=343.1618957519531, x_2=968.259521484375, y_2=1253.485107421875), text=None, id=None, type=Figure, parent=None, next=None, score=0.9465294480323792)], page_data={})
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=239.98239135742188, y_1=940.641845703125, x_2=937.1505126953125, y_2=1189.1998291015625), text=None, id=None, type=List, parent=None, next=None, score=0.9333369135856628), TextBlock(block=Rectangle(x_1=77.1417465209961, y_1=76.79753875732422, x_2=869.6155395507812, y_2=966.9711303710938), text=None, id=None, type=Figure, parent=None, next=None, score=0.7248597145080566)], page_data={})
# Saved to scrape_out_old/General - Mandell - Core Radiology (1e)/ch12.json

# %%
from pdfplumber.page import Page
from collections import deque

def process_page(pg: Page):
    assert not isinstance(pg, pdfplumber.page.CroppedPage)
    assert pg.textboxhorizontals, "Pass `laparams={...}` when opening the PDF file"

    if (pg.page_number % 2) and config["odd_spread"]:
        crop_box = (
            config["crop_outer"],
            config["crop_top"],
            pg.width - config["crop_inner"],
            pg.height - config["crop_bot"],
        )
    else:
        crop_box = (
            config["crop_inner"],
            config["crop_top"],
            pg.width - config["crop_outer"],
            pg.height - config["crop_bot"],
        )

    pg_crop = pg.within_bbox(crop_box)
    # pg.to_image(resolution=123).draw_rects(pg_crop.textboxhorizontals).show()
    # pg.to_image(resolution=123).draw_rects(pg_crop.extract_words()).show()

    continuation = ""  # base text continuing from previous page's last entry
    mode = "startup"  # startup, header, body
    entries = []  # list of (header, text) tuples
    current_entry = ["", ""]  # current entry (header, text)

    last_y = float("inf")

    # todo can I pass args s.t. this correctly parses two columns; or figure out how to order via x0/x1
    for i, box in enumerate(pg_crop.textboxhorizontals):  # [26:27]
        # text = box['text']
        # text = re.sub(r'\n', ' ', text)
        # text = re.sub(r'\s+', ' ', text)
        # words = text.split()
        # print(words)
        # if len(words) < 4: continue

        x0, y0, x1, y1 = box["x0"], box["y0"], box["x1"], box["y1"]
        bbox = (x0, pg.height - y1, x1, pg.height - y0)  # = (x0, y0, x1, y1)
        pg_bbox = pg.crop(bbox, relative=True)

        if mode == "body" and not (
            abs(y1 - last_y) > 0.8 * pg.height
        ):  # condition of text continuation across columns
            current_entry[1] += "\n"

        last_y = y0

        chars = deque(
            [
                c
                for c in pg_bbox.chars
                if c["fontname"] not in config["font_ignore_names"]
            ]
        )
        # print([c for c in pg_bbox.chars if c['fontname'] in config["font_ignore_names"]])
        words = pg_bbox.extract_words()

        # pg_bbox.to_image(resolution=150).draw_rects(chars).show()

        for w in words:
            # ! TODO Find a better way to do this
            try:
                while not w["text"][0].startswith(chars[0]["text"]):
                    # print(w["text"], chars[0]["text"])
                    chars.popleft()

                # if chars:
                #     chars.popleft()
            except IndexError as e:
                #  "".join([w["text"] for w in words])
                print(f"Box {i}: Could not parse the box of text: {e}")
                print(" ".join([w["text"] for w in words]))
                print("".join([c["text"] for c in pg_bbox.chars]))
                break

            txt = w["text"].strip()
            if txt.endswith("-") and abs(w["x1"] - x1) < 0.08 * pg.width:
                txt = txt[:-1]
            else:
                txt = txt + " "

            fname = chars[0]["fontname"]
            if fname in config["font_header_names"]:
                match mode:
                    case "startup":
                        mode = "header"
                        current_entry = [txt, ""]
                    case "header":
                        current_entry[0] += txt
                    case "body":
                        mode = "header"
                        entries.append([ent.strip() for ent in current_entry])
                        current_entry = [txt, ""]
            elif fname in config["font_body_names"]:
                match mode:
                    case "startup":
                        continuation += txt
                    case "header":
                        mode = "body"
                        current_entry[1] += txt
                    case "body":
                        current_entry[1] += txt
            elif fname in config["font_ignore_names"]:
                continue
            else:
                print(f"Unknown font {fname}: '{txt}'")
                # pg_bbox.to_image(resolution=123).draw_rects(chars).show()

        # pg_bbox.to_image(resolution=150).show()
        # pg_bbox.to_image(resolution=150).draw_rects(chars).show()

    return entries, continuation


ent, cont = process_page(pg)
print("cont:", cont, "\n")
for h, b in ent:
    print("**", h, "**")
    print(b)
    print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 121
#     113                 # pg_bbox.to_image(resolution=123).draw_rects(chars).show()
#     114
#     115         # pg_bbox.to_image(resolution=150).show()
#     116         # pg_bbox.to_image(resolution=150).draw_rects(chars).show()
#     118     return entries, continuation
# --> 121 ent, cont = process_page(pg)
#     122 print("cont:", cont, "\n")
#     123 for h, b in ent:
#
# Cell In[24], line 17, in process_page(pg)
#       9     crop_box = (
#      10         config["crop_outer"],
#      11         config["crop_top"],
#      12         pg.width - config["crop_inner"],
#      13         pg.height - config["crop_bot"],
#      14     )
#      15 else:
#      16     crop_box = (
# ---> 17         config["crop_inner"],
#      18         config["crop_top"],
#      19         pg.width - config["crop_outer"],
#      20         pg.height - config["crop_bot"],
#      21     )
#      23 pg_crop = pg.within_bbox(crop_box)
#      24 # pg.to_image(resolution=123).draw_rects(pg_crop.textboxhorizontals).show()
#      25 # pg.to_image(resolution=123).draw_rects(pg_crop.extract_words()).show()
#
# TypeError: 'Config' object is not subscriptable

# %% [markdown]
# ### `fitz`

# %%
class Config:
    # todo typeing for font_* sets
    odd_spread = True  # inner corresponds to right-side of odd pages, left-side of even pages
    crop_top: int = 0
    crop_inner: int = 0
    crop_bot: int = 0
    crop_outer: int = 0
    font_header: Set[Tuple[int, str]] = set()
    font_body: Set[Tuple[int, str]] = set()
    font_ignore: Set[Tuple[int, str]] = set()
    font_ignore_names: Set[str] = set()
    chapters: List[int] = None

    def __init__(self, fname: Path):
        match fname.name:
            case "Chest - Elicker - HRCT of the Lungs 2e.pdf":
                self.crop_top = 65
                self.crop_inner = 40
                self.crop_bot = 30
                self.crop_outer = 40
                self.chapters = [49, 62, 83, 104, 116, 129, 150, 166, 174, 199, 212, 221, 233, 247, 265, 274, 283, 296, 305]
                
            case "Chest - Felson - Principles of Chest Roentgenology (4e).pdf":
                self.crop_top = 50
                self.crop_inner = 40
                self.crop_bot = 50
                self.crop_outer = 50
                self.chapters = [8,29,46,68,84,104,122,136,160,182,202,226] # TODO rest of chpts

            case "Chest - Webb - Fundamentals of Body CT (4e).pdf":
                self.crop_top = 60
                self.crop_inner = 40
                self.crop_bot = 30
                self.crop_outer = 30
                self.font_header = {(13.0, 'Univers-CondensedBold'), (10.0, 'Univers-BoldOblique')}
                self.font_body = {
                    (10.0, "JansonText-Roman"),
                    (10.0, "JansonText-Italic"),
                    (10.0, 'JansonText-Bold'),
                    (10.0, 'JansonText-BoldItalic'),
                    (10.0, 'TnQ'), # greek characters
                }
                self.font_ignore = {
                    (16.0, "JansonText-Roman"),  # chapter title font
                    (7.199999809265137, "JansonText-Roman-SC800"),
                    (9.0, "JansonText-Roman-SC800"),
                    (27.0, "JansonText-Roman-SC800"),
                    (21.600000381469727, "JansonText-Roman-SC800"),
                    (8.0, 'Univers-CondensedBold'), # figure labels
                    # (9.0, 'JansonText-Bold'), # todo these are numbers; verify they're not needed
                    (8.0, 'Univers-BoldOblique'), # figure labels
                    (10.0, 'Univers-CondensedBold'), # page numbers
                    (16.0, 'JansonText-Bold'), # chapter number
                }
                self.font_ignore_names = {'Helvetica',   # figures
                                          'Helvetica-Bold',
                                          'ZapfDingbats', # bullet points
                                          'Univers', # table body
                                          'Univers-Light', # table footer
                                          'Univers-Oblique', # figure arrows
                                          'Univers-Bold', # table header
                                          'Univers-Condensed', # table label
                                        #   'Sabon-Roman'
                }
                # Chapters are zero-indexed, and final number is the last page of the final chapter
                self.chapters = [6,12,26,49,73,94,134,151,176,188,214,225,241,250,278,290,323,340,349,363,370,]
            case "General - Mandell - Core Radiology (1e).pdf":
                self.crop_top = 10
                self.crop_inner = 30
                self.crop_bot = 30
                self.crop_outer = 30
                self.font_header = {(11.0, 'TwCenMT-CondensedExtraBo'),
                                    (18.0, 'Calibri-Bold'),
                                    (14.0, 'Calibri-Bold'),}    
                self.font_body = {(12.0, 'Calibri'),(10.0, 'Calibri'),(10.0, 'Calibri-Bold')}
                self.font_ignore_names = {'ArialMT','MyriadPro-Regular','MyriadPro-It','Wingdings2'}
                self.font_ignore = {(-1, ''),} 
                self.chapters = [669,702]
            case _:
                raise KeyError
            
        
        overlapping_fonts = self.font_ignore_names.intersection([x[1] for x in self.font_body.union(self.font_header)])
        assert not overlapping_fonts, f"These fonts are both ignored and included: {overlapping_fonts}"

    def chapter_range(self):
        return list(zip(self.chapters, self.chapters[1:]))

    def contained_chapter(self, page: fitz.Page, chapter_range=None):
        chapter_range = chapter_range or self.chapter_range()
        for i, (start, end) in enumerate(chapter_range):
            if (start or float("-inf")) <= page.number < (end or float("inf")):
                return i
        return None

    def get_cropbox(self, pg: fitz.Page):
        inr, outr = self.crop_inner, self.crop_outer
        if ((pg.number + 1) % 2) and config.odd_spread:
            inr, outr = outr, inr

        return (
            outr,
            config.crop_top,
            pg.rect.width - inr,
            pg.rect.height - config.crop_bot,
        )

    def crop_page(self, pg: fitz.Page):
        if pg.cropbox_position == fitz.Point():  # botched to check if cropbox is not set
            crop_box = self.get_cropbox(pg)
            pg.set_cropbox(crop_box)


config = Config(fname)

# config.chapter_range()

# %%
pdf = fitz.open(fname)
# pages = pdf[config['pg_start']:]
start, end = config.chapter_range()[0]
# print(start,end)

# pages = pdf[start:end]

pdf.select(range(start, end))

print(len(pdf))

pg: fitz.Page = pdf[1]
# print(pg.get_text())

# %%
def page_to_img(pg: fitz.Page, config=config):
    im: fitz.Pixmap = pg.get_pixmap(clip=config.get_cropbox(pg))
    bytes = im.tobytes("png")
    return Image.open(BytesIO(bytes))

# crop_page(pg)
im=page_to_img(pg)

plt.figure(figsize=(10,10))
display(im)

# %%
def process_page(pg: fitz.Page):
    # page_to_img(pg).show()

    continuation = ""  # base text continuing from previous page's last entry
    mode = "startup"  # startup, header, body
    entries = []  # list of (header, text) tuples
    current_entry = ["", ""]  # current entry (header, text)
    done = False # whether we've reached the end of the chapter (e.x. sugguested readings section)

    flags = fitz.TEXTFLAGS_DICT & ~fitz.TEXT_PRESERVE_IMAGES & fitz.TEXT_DEHYPHENATE

    # tessdata=Path('/usr/share/tessdata')
    tp = pg.get_textpage(flags=flags)   # default behavior
    # tp = pg.get_textpage_ocr(flags=flags, full=True, dpi=300, tessdata=tessdata)   # full
    # tp = pg.get_textpage_ocr(flags=flags, full=False, tessdata=tessdata)   # partial

    dict = pg.get_text("dict", textpage=tp, flags=flags, clip=config.get_cropbox(pg))
    blocks = dict["blocks"]
    for block in blocks:
        for line in block["lines"]:
            for span in line["spans"]:
                txt = span["text"]

                if txt == 'SUGGESTED READING':
                    print('### Found end of chapter, stopping early ### ')
                    done = True
                    if mode == "body":
                        entries.append([ent.strip() for ent in current_entry])
                    return entries, continuation.strip(), done

                # if txt.endswith("-") and abs(w["x1"] - x1) < 0.08 * pg.width:

                font = (span["size"], span["font"])
                # print(font, txt)
                if font in config.font_ignore or span["font"] in config.font_ignore_names:
                    continue
                elif font in config.font_header:
                    match mode:
                        case "startup":
                            mode = "header"
                            current_entry = [txt, ""]
                        case "header":
                            current_entry[0] += txt
                        case "body":
                            mode = "header"
                            entries.append([ent.strip() for ent in current_entry])
                            current_entry = [txt, ""]
                elif font in config.font_body:
                    match mode:
                        case "startup":
                            if txt.endswith("."):
                                txt += "\n"
                            continuation += txt
                        case "header":
                            mode = "body"
                            current_entry[1] += txt
                        case "body":
                            if txt.endswith("."):
                                txt += "\n"
                            current_entry[1] += txt
                else:
                    if txt.strip():
                        print(f"Page {pg.number}: unknown font-pair {font}, ignoring text: '{txt}'")

    match mode:
        case "body":
            entries.append([ent.strip() for ent in current_entry])
        case "header", "startup":
            print("### Ended on", mode, "-- this should not happen")
    
            
    continuation = process_text(continuation)
    for i, (_h, b) in enumerate(entries):
        entries[i][1] = process_text(b)

    return entries, continuation, done


ent, cont, done = process_page(pg)


print('\n' + '='*80)
print("cont:", cont, "\n")
for h, b in ent:
    print("**", h, "**")
    print(b)
    print()
